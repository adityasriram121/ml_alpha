# %% [markdown]
# # 🏋️ Practice Problems: 14_REINFORCEMENT_LEARNING
# ## Reinforcement Learning Basics
#
# **Topics**: bandits, MDPs, value iteration, Q-learning, policy gradient
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What is reinforcement learning? How is it different from supervised learning?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>No labels, learn from rewards via interaction.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain the exploration-exploitation tradeoff.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Explore: try new actions. Exploit: use best known.</details>

# %% [markdown]
# **Q3-Q35.** Continue with more conceptual problems on MDPs, value functions, Q-functions, policies, Bellman equation.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Derive the Bellman equation: V(s) = Σ_a π(a|s) Σ_s' P(s'|s,a)[r + γV(s')].

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Recursive expectation of reward + future value.</details>

# %% [markdown]
# **Q37-Q65.** Continue with Bellman optimality, Q-learning, value/policy iteration convergence.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Implement epsilon-greedy bandit solver. On 3-armed bandit, learn which arm is best.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>Explore with prob ε, exploit otherwise.</details>

# %% [markdown]
# **Q67-Q100.** Continue with value iteration, Q-learning, policy gradient.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
