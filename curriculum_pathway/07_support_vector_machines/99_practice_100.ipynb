# %% [markdown]
# # 🏋️ Practice Problems: 07_SUPPORT_VECTOR_MACHINES
# ## Support Vector Machines & Kernels
#
# **Topics**: SVM margin, kernel trick, soft margin, multi-class SVM
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What is the margin in SVM? Why do we want to maximize it?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Distance from decision boundary to nearest points. Larger = more robust.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain the kernel trick. Why does it avoid explicit transformation?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Compute K(x_i, x_j) instead of φ(x_i)^T φ(x_j).</details>

# %% [markdown]
# **Q3-Q35.** Continue with more conceptual problems on support vectors, soft margin, RBF kernel, multi-class.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Derive the SVM optimization problem: maximize 1/||w|| subject to y_i(w^T x_i + b) ≥ 1.

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Margin = 2/||w||.</details>

# %% [markdown]
# **Q37-Q65.** Continue with theoretical problems on kernel trick, RBF, duality, KKT conditions.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Fit linear SVM on Iris binary (setosa vs others). Report accuracy and num support vectors.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>Use SVC(kernel='linear').</details>

# %% [markdown]
# **Q67-Q100.** Continue with RBF kernel, polynomial, gamma tuning, GridSearchCV.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
