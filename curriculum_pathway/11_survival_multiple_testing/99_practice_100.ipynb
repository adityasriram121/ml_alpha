# %% [markdown]
# # 🏋️ Practice Problems: 11_SURVIVAL_MULTIPLE_TESTING
# ## Statistical Inference & Multiple Testing
#
# **Topics**: hypothesis testing, p-values, multiple testing correction, false discovery rate
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What is a p-value? What does p < 0.05 mean?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Prob of observing data if null hypothesis is true.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain Type I and Type II errors. Which is worse?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Context-dependent. Type I = false positive.</details>

# %% [markdown]
# **Q3-Q35.** Continue with more conceptual problems on multiple testing, FDR, FWER, confidence intervals.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Derive the t-statistic: t = (x̄ - μ) / (s / √n).

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Standardized difference.</details>

# %% [markdown]
# **Q37-Q65.** Continue with theoretical problems on Bonferroni, Benjamini-Hochberg, FDR, power.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Simulate data from null hypothesis. Compute 1000 p-values. Plot histogram. Are they uniform?

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>Should see flat distribution.</details>

# %% [markdown]
# **Q67-Q100.** Continue with t-tests, multiple testing corrections, FDR procedures.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
