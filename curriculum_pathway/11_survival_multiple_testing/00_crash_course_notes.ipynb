# %% [markdown]
# # Concept 11: Survival Analysis & Multiple Testing (Crash Course Notes)
#
# Time-to-event outcomes and correcting statistical hypothesis thresholds.
#
# ## 📖 Readings Reference
# * **ISLP**: Chapter 11 (Survival) & Chapter 13 (Multiple Testing).
#
# ## 📐 Mathematical Foundations
# 1. **Kaplan-Meier Estimator**:
#    $$\hat{S}(t) = \prod_{t_i \le t} \left(1 - \frac{d_i}{n_i}\right)$$
# 2. **Bonferroni Correction**:
#    $$\alpha_{adj} = \frac{\alpha}{m}$$
# 3. **Benjamini-Hochberg (FDR Control)**:
#    $$p_{(i)} \le \frac{i}{m} q$$
#
# ---
#
# ## 💻 Coding Tasks (Your Turn)

# %%
# Task 1: Bonferroni p-value Adjustments
# Adjust an array of raw p-values using Bonferroni correction (cap at 1.0).
def bonferroni_correct(p_values):
    m = len(p_values)
    ### YOUR CODE HERE
    p_adj = None
    ### END CODE
    return p_adj

# %% [markdown]
# ## ❓ Socratic Checkpoints
# 1. What does **right-censoring** mean in survival analysis datasets?
# 2. Explain the difference between controlling the Family-Wise Error Rate (FWER) and the False Discovery Rate (FDR). Which is more conservative?
# 3. How does the Cox Proportional Hazards model incorporate regression features into survival probability estimation?
