# %% [markdown]
# # 🏋️ Practice Problems: 03_CLASSIFICATION
# ## Logistic Regression & Classification Metrics
#
# **Topics covered**: logistic regression, decision boundaries, precision/recall/F1, ROC/AUC, imbalanced data
#
# This notebook contains 100 practice problems:
# - 🧠 **Conceptual** (Q1-Q35): Explain, compare, true/false with justification
# - 📐 **Theoretical** (Q36-Q65): Derivations, proofs, mathematical formulations
# - 💻 **Practical** (Q66-Q100): Code implementations, data analysis, plotting
#
# **Difficulty levels**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)
#
# **Datasets**: Iris, synthetic binary

# %% [markdown]
# ## 🧠 Conceptual Problems (Q1 - Q35)

# %% [markdown]
# **Q1.** [⭐] What is logistic regression? Why is it called 'regression' if used for classification?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Predicts log-odds (logit), converts to probabilities with sigmoid.
#
# </details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain the sigmoid function and why it's used in logistic regression.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# σ(z) = 1/(1+e^-z). Maps ℝ to (0,1).
#
# </details>

# %% [markdown]
# **Q3.** [⭐⭐] Define: precision, recall, F1-score. When optimize for each?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Precision=TP/(TP+FP), Recall=TP/(TP+FN). Depends on use case.
#
# </details>

# %% [markdown]
# **Q4-Q35.** Fill in with additional conceptual problems.

# %% [markdown]
# ## 📐 Theoretical Problems (Q36 - Q65)

# %% [markdown]
# **Q36.** [⭐] Derive sigmoid from odds. Show σ(-z) = 1 - σ(z).

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# odds = p/(1-p). Solve for p. Use e^-z = 1/e^z.
#
# </details>

# %% [markdown]
# **Q37.** [⭐⭐] Derive cross-entropy loss for binary classification. Show it's -[y*log(p) + (1-y)*log(1-p)].

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use log-likelihood as negative loss.
#
# </details>

# %% [markdown]
# **Q38-Q65.** Fill in with additional theoretical problems.

# %% [markdown]
# ## 💻 Practical Problems (Q66 - Q100)

# %% [markdown]
# **Q66.** [⭐] Create binary dataset: Iris setosa (class 1) vs others (class 0). Split 80/20.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use sklearn.datasets or load iris.
#
# </details>

# %% [markdown]
# **Q67.** [⭐⭐] Fit logistic regression. Report accuracy, precision, recall, F1, AUC on test set.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use sklearn.metrics for all scores.
#
# </details>

# %% [markdown]
# **Q68-Q100.** Fill in with additional practical problems.

# %% [markdown]
# ---
#
# ## 📝 How to use this notebook:
#
# 1. **Work through problems in order** within each section
# 2. **Use hints liberally** — they point you in the right direction
# 3. **Compare with solutions** after completing (once posted)
# 4. **Challenge yourself** — skip to harder problems (⭐⭐⭐) if you're comfortable
# 5. **Revisit regularly** — revisiting problems helps consolidate learning
#
# Good luck! 🚀
