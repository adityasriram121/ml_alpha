# %% [markdown]
# # Concept 03: Classification & Decision Boundaries (Crash Course Notes)
#
# Focuses on mapping features to discrete classes.
#
# ## 📖 Readings Reference
# * **ISLP**: Chapter 4 (Classification).
# * **HOML3**: Chapter 3 (Classification) & Chapter 4 (Logistic Regression sections).
#
# ## 📐 Mathematical Foundations
# 1. **Odds and Log-Odds**:
#    $$\text{Odds} = \frac{p}{1-p}, \quad \text{Log-Odds (Logit)} = \log\left(\frac{p}{1-p}\right)$$
# 2. **Sigmoid Mapping**:
#    $$\sigma(z) = \frac{1}{1 + e^{-z}}$$
#
# ---
#
# ## 💻 Coding Tasks (Your Turn)

# %%
# Task 1: Sigmoid Activation
def sigmoid(z):
    ### YOUR CODE HERE
    return None
    ### END CODE

# %% [markdown]
# ## ❓ Socratic Checkpoints
# 1. What does the ROC Curve represent, and how does the Area Under the Curve (AUC) evaluate classification quality?
# 2. If your dataset has severe class imbalance (e.g. 99% negative, 1% positive), why is Accuracy a terrible metric? What should you use instead?
# 3. How does Logistic Regression generalize to multiclass classification (Softmax / Multinomial Regression)?
