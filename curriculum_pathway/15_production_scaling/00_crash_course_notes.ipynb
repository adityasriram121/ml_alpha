# %% [markdown]
# # Concept 15: Production & Scaled ML (Crash Course Notes)
#
# Packaging, serving, and deploying models to cloud pipelines and edge devices.
#
# ## 📖 Readings Reference
# * **HOML3**: Chapter 19 (Scaling & Deploying).
#
# ## 📐 Mathematical Foundations
# 1. **Model Latency**: Measures inference response delay:
#    $$\text{Latency} = T_{inference} - T_{request}$$
# 2. **Throughput**: Number of inferences per second:
#    $$\text{Throughput} = \frac{N_{samples}}{\Delta T}$$
#
# ---
#
# ## 💻 Coding Tasks (Your Turn)

# %%
# Task 1: Measure inference throughput
import time

def measure_throughput(model_func, data, n_runs=100):
    start = time.time()
    for _ in range(n_runs):
        _ = model_func(data)
    total_time = time.time() - start
    ### YOUR CODE HERE
    throughput = None
    ### END CODE
    return throughput

# %% [markdown]
# ## ❓ Socratic Checkpoints
# 1. Explain the advantage of using TF Serving instead of wrapping a model in a raw Flask/FastAPI REST wrapper.
# 2. How does model quantization (TFLite) shrink model footprint? What are the precision side-effects?
# 3. What is the purpose of Docker containerization in maintaining reproducibility during deployment?
