# %% [markdown]
# # 🏋️ Custom Practice: 03 End To End Machine Learning Project
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Get the Data

# %% [markdown]
# **✨ Task:** Write a function to dynamically download a dataset from a given URL and extract it into a local directory.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Download the Data

# %% [markdown]
# **✨ Task:** Practice Exercise for **Download the Data**:
# Implement a small, self-contained example demonstrating the core concept of Download the Data. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Take a Quick Look at the Data Structure

# %% [markdown]
# **✨ Task:** Practice Exercise for **Take a Quick Look at the Data Structure**:
# Implement a small, self-contained example demonstrating the core concept of Take a Quick Look at the Data Structure. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Create a Test Set

# %% [markdown]
# **✨ Task:** Practice Exercise for **Create a Test Set**:
# Implement a small, self-contained example demonstrating the core concept of Create a Test Set. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Discover and Visualize the Data to Gain Insights

# %% [markdown]
# **✨ Task:** Load the housing dataset and plot histograms for every numerical attribute using `.hist(bins=50)`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Visualizing Geographical Data

# %% [markdown]
# **✨ Task:** Practice Exercise for **Visualizing Geographical Data**:
# Implement a small, self-contained example demonstrating the core concept of Visualizing Geographical Data. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Looking for Correlations

# %% [markdown]
# **✨ Task:** Practice Exercise for **Looking for Correlations**:
# Implement a small, self-contained example demonstrating the core concept of Looking for Correlations. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Experimenting with Attribute Combinations

# %% [markdown]
# **✨ Task:** Practice Exercise for **Experimenting with Attribute Combinations**:
# Implement a small, self-contained example demonstrating the core concept of Experimenting with Attribute Combinations. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Prepare the Data for Machine Learning Algorithms

# %% [markdown]
# **✨ Task:** Create a scikit-learn `Pipeline` that fills missing values with the median and applies a StandardScaler.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# **✨ Task:** Practice Exercise for **Data Cleaning**:
# Implement a small, self-contained example demonstrating the core concept of Data Cleaning. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Handling Text and Categorical Attributes

# %% [markdown]
# **✨ Task:** Practice Exercise for **Handling Text and Categorical Attributes**:
# Implement a small, self-contained example demonstrating the core concept of Handling Text and Categorical Attributes. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Feature Scaling

# %% [markdown]
# **✨ Task:** Practice Exercise for **Feature Scaling**:
# Implement a small, self-contained example demonstrating the core concept of Feature Scaling. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Custom Transformers

# %% [markdown]
# **✨ Task:** Practice Exercise for **Custom Transformers**:
# Implement a small, self-contained example demonstrating the core concept of Custom Transformers. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Transformation Pipelines

# %% [markdown]
# **✨ Task:** Practice Exercise for **Transformation Pipelines**:
# Implement a small, self-contained example demonstrating the core concept of Transformation Pipelines. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Select and Train a Model

# %% [markdown]
# **✨ Task:** Train a simple Linear Regression model on your prepared data and calculate the RMSE on the training set.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Training and Evaluating on the Training Set

# %% [markdown]
# **✨ Task:** Practice Exercise for **Training and Evaluating on the Training Set**:
# Implement a small, self-contained example demonstrating the core concept of Training and Evaluating on the Training Set. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Better Evaluation Using Cross-Validation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Better Evaluation Using Cross-Validation**:
# Implement a small, self-contained example demonstrating the core concept of Better Evaluation Using Cross-Validation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Fine-Tune Your Model

# %% [markdown]
# **✨ Task:** Use `GridSearchCV` to test 3 different hyperparameter combinations for a RandomForestRegressor.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Grid Search

# %% [markdown]
# **✨ Task:** Practice Exercise for **Grid Search**:
# Implement a small, self-contained example demonstrating the core concept of Grid Search. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Randomized Search

# %% [markdown]
# **✨ Task:** Practice Exercise for **Randomized Search**:
# Implement a small, self-contained example demonstrating the core concept of Randomized Search. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Analyze the Best Models and Their Errors

# %% [markdown]
# **✨ Task:** Practice Exercise for **Analyze the Best Models and Their Errors**:
# Implement a small, self-contained example demonstrating the core concept of Analyze the Best Models and Their Errors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Evaluate Your System on the Test Set

# %% [markdown]
# **✨ Task:** Run your final model on the hold-out test set and compute the final test RMSE and a 95% confidence interval.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Model persistence using joblib

# %% [markdown]
# **✨ Task:** Practice Exercise for **Model persistence using joblib**:
# Implement a small, self-contained example demonstrating the core concept of Model persistence using joblib. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Exercise solutions

# %% [markdown]
# **✨ Task:** Practice Exercise for **Exercise solutions**:
# Implement a small, self-contained example demonstrating the core concept of Exercise solutions. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 1.

# %% [markdown]
# **✨ Task:** Practice Exercise for **1.**:
# Implement a small, self-contained example demonstrating the core concept of 1.. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 2.

# %% [markdown]
# **✨ Task:** Practice Exercise for **2.**:
# Implement a small, self-contained example demonstrating the core concept of 2.. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 3.

# %% [markdown]
# **✨ Task:** Practice Exercise for **3.**:
# Implement a small, self-contained example demonstrating the core concept of 3.. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 4.

# %% [markdown]
# **✨ Task:** Practice Exercise for **4.**:
# Implement a small, self-contained example demonstrating the core concept of 4.. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 5.

# %% [markdown]
# **✨ Task:** Practice Exercise for **5.**:
# Implement a small, self-contained example demonstrating the core concept of 5.. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 6.

# %% [markdown]
# **✨ Task:** Practice Exercise for **6.**:
# Implement a small, self-contained example demonstrating the core concept of 6.. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
