# %% [markdown]
# # 🏋️ Custom Practice: 02 Ch02-Statlearn-Lab
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# ## Getting Started

# %% [markdown]
# **✨ Task:** Practice Exercise for **Getting Started**:
# Implement a small, self-contained example demonstrating the core concept of Getting Started. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Basic Commands

# %% [markdown]
# **✨ Task:** Practice basic python list comprehensions and math operations related to statistical learning.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Introduction to Numerical Python

# %% [markdown]
# **✨ Task:** Practice Exercise for **Introduction to Numerical Python**:
# Implement a small, self-contained example demonstrating the core concept of Introduction to Numerical Python. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Graphics

# %% [markdown]
# **✨ Task:** Use matplotlib or seaborn to create a basic scatter plot of a dataset. Add proper titles and labels.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Sequences and Slice Notation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Sequences and Slice Notation**:
# Implement a small, self-contained example demonstrating the core concept of Sequences and Slice Notation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Indexing Data

# %% [markdown]
# **✨ Task:** Practice Exercise for **Indexing Data**:
# Implement a small, self-contained example demonstrating the core concept of Indexing Data. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Boolean Indexing

# %% [markdown]
# **✨ Task:** Practice Exercise for **Boolean Indexing**:
# Implement a small, self-contained example demonstrating the core concept of Boolean Indexing. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Loading Data

# %% [markdown]
# **✨ Task:** Use pandas to load a dataset from a URL or local CSV. Print the first 5 rows and data types.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Reading in a Data Set

# %% [markdown]
# **✨ Task:** Practice Exercise for **Reading in a Data Set**:
# Implement a small, self-contained example demonstrating the core concept of Reading in a Data Set. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Basics of Selecting Rows and Columns

# %% [markdown]
# **✨ Task:** Practice Exercise for **Basics of Selecting Rows and Columns**:
# Implement a small, self-contained example demonstrating the core concept of Basics of Selecting Rows and Columns. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### More on Selecting Rows and Columns

# %% [markdown]
# **✨ Task:** Practice Exercise for **More on Selecting Rows and Columns**:
# Implement a small, self-contained example demonstrating the core concept of More on Selecting Rows and Columns. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### String Formatting

# %% [markdown]
# **✨ Task:** Practice Exercise for **String Formatting**:
# Implement a small, self-contained example demonstrating the core concept of String Formatting. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Additional Graphical and Numerical Summaries

# %% [markdown]
# **✨ Task:** Use pandas `.describe()` to get summary statistics, and `.corr()` to view a correlation matrix.

# %%
# YOUR CODE HERE
