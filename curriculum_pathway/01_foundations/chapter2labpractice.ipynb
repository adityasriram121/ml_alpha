# %% [markdown]
# # ISLP Chapter 2: Statistical Learning Worksheet
#
# **Instructions:** Answer all 100 questions below. For conceptual questions, provide a brief answer. For programming drills, write and execute the Python code.

# %% [markdown]
# ## Part I: Conceptual & Mathematical Foundations

# %% [markdown]
# ### Section 1: The Core Paradigm & Trade-Offs (Questions 1-15)

# %% [markdown]
# **Question 1:** In the core paradigm equation `Y = f(X) + epsilon`, what does `Y` represent?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 2:** What does `X` represent in the equation?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 3:** What does the term `f(X)` symbolize? Why do we want to estimate it?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 4:** What does the `epsilon` term represent? Give two examples of what might cause it.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 5:** What is the expectation of the irreducible error, mathematically expressed? (Use plain text format, e.g., `E[epsilon] = ?`)

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 6:** What are the two main reasons we estimate `f(X)`?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 7:** Describe a scenario where you would prioritize **Prediction** over **Inference**.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 8:** Describe a scenario where **Inference** is more important than **Prediction**.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 9:** If interpretability is your main goal, would you choose a linear model or a deep neural network?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 10:** What are Parametric methods? What are the two steps involved in their fit?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 11:** What is the main advantage and the main disadvantage of Parametric methods?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 12:** What are Non-Parametric methods, and what is their primary advantage?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 13:** Why do Non-Parametric methods generally require a larger number of observations than Parametric methods?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 14:** Explain the Flexibility vs. Interpretability trade-off in one sentence.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 15:** Order the following from most interpretable to most flexible: Support Vector Machines, Linear Regression, Random Forests, Lasso.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# ### Section 2: Assessing Model Accuracy (Questions 16-25)

# %% [markdown]
# **Question 16:** Write out the formula for Mean Squared Error (MSE) using plain text/ASCII math.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 17:** What is the difference between Training MSE and Test MSE?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 18:** True or False: We always want to choose the model that minimizes the Training MSE.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 19:** Describe the general shape of the Test MSE curve as model flexibility increases.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 20:** What is overfitting? How does it relate to the `epsilon` term?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 21:** Write out the mathematical decomposition of Expected Test MSE. (e.g., `E[(y_0 - f_hat(x_0))^2] = ?`)

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 22:** In the Bias-Variance trade-off, what does **Variance** measure?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 23:** In the Bias-Variance trade-off, what does **Bias** measure?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 24:** If a model is **Underfitting**, what are its typical levels of Bias and Variance?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 25:** If a model is **Overfitting**, what are its typical levels of Bias and Variance?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# ### Section 3: Classification & KNN (Questions 26-35)

# %% [markdown]
# **Question 26:** How is the Error Rate calculated in a classification setting? (Explain the indicator function `I(y_i != y_hat_i)`).

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 27:** What is the Bayes Classifier?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 28:** What is the Bayes Decision Boundary?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 29:** What does KNN stand for?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 30:** Briefly explain how KNN classifies a new observation `x_0`.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 31:** In KNN, if we set `K = 1`, is the decision boundary highly flexible or highly restrictive?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 32:** For `K = 1`, describe the model's Bias and Variance.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 33:** If we set `K = 100`, what happens to the flexibility of the decision boundary?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 34:** For `K = 100`, describe the model's Bias and Variance.

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# **Question 35:** In practice, why can't we just use the Bayes Classifier instead of KNN?

# %% [markdown]
# *Your Answer Here*

# %% [markdown]
# ## Part II: Practical Programming & Lab Drills
# For these questions, write and execute the Python code in the cells provided.

# %% [markdown]
# ### Section 4: Python Lists & Basics (Questions 36-45)

# %% [markdown]
# **Question 36:** Create two Python lists, `x_list` containing `[1, 2, 3]` and `y_list` containing `[4, 5, 6]`.

# %%
x_list = 
y_list =

# %% [markdown]
# **Question 37:** Concatenate `x_list` and `y_list` using the `+` operator. What is the output?

# %% [markdown]
# **Question 38:** Why didn't the `+` operator add the elements together element-wise?

# %%
# Write your answer as a comment

# %% [markdown]
# **Question 39:** Append the number `7` to `x_list`.

# %% [markdown]
# **Question 40:** Find the length of `y_list`.

# %% [markdown]
# **Question 41:** Access the second element of `x_list`.

# %% [markdown]
# **Question 42:** Create a list of lists called `matrix_list` containing `[[1,2], [3,4]]`.

# %% [markdown]
# **Question 43:** Access the value `3` from `matrix_list` using multiple indexing.

# %% [markdown]
# **Question 44:** Write a for loop that prints each element in `y_list`.

# %% [markdown]
# **Question 45:** Use a list comprehension to create a new list containing the squares of all elements in `x_list`.

# %% [markdown]
# ### Section 5: NumPy Arrays & Element-wise Operations (Questions 46-60)

# %% [markdown]
# **Question 46:** Import the numpy library as `np`.

# %%
import numpy as np

# %% [markdown]
# **Question 47:** Convert `x_list` and `y_list` from Question 36 into numpy arrays called `x_arr` and `y_arr`. (Note: ensure they have the same length by redefining them as `[1,2,3]` and `[4,5,6]`)

# %%
x_arr = np.array([1, 2, 3])
y_arr = np.array([4, 5, 6])

# %% [markdown]
# **Question 48:** Add `x_arr` and `y_arr` using the `+` operator. Notice the difference from list concatenation.

# %% [markdown]
# **Question 49:** Multiply `x_arr` and `y_arr` element-wise.

# %% [markdown]
# **Question 50:** Square every element in `x_arr`.

# %% [markdown]
# **Question 51:** Find the sum of all elements in `y_arr`.

# %% [markdown]
# **Question 52:** Calculate the mean of `x_arr`.

# %% [markdown]
# **Question 53:** Calculate the variance of `y_arr`.

# %% [markdown]
# **Question 54:** Calculate the standard deviation of `x_arr`.

# %% [markdown]
# **Question 55:** Create an array of 10 zeros.

# %% [markdown]
# **Question 56:** Create an array of 5 ones.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 np.one(5)
#
# File c:\Users\adisr\OneDrive\Documents\ml\ml_alpha\.venv\Lib\site-packages\numpy\__init__.py:805, in __getattr__(attr)
#     802     import numpy.char as char
#     803     return char.chararray
# --> 805 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'one'

# %% [markdown]
# **Question 57:** Use `np.arange` to create an array from 0 to 9.

# %% [markdown]
# **Question 58:** Use `np.linspace` to create an array of 5 evenly spaced numbers between 0 and 1.

# %% [markdown]
# **Question 59:** Add the scalar value `10` to `x_arr` (Broadcasting example).

# %% [markdown]
# **Question 60:** Multiply `y_arr` by the scalar value `5`.

# %% [markdown]
# ### Section 6: Matrix Dimensions & Slicing (Questions 61-75)

# %% [markdown]
# **Question 61:** Create a 2D numpy array called `matrix` representing: `[[1, 2, 3], [4, 5, 6], [7, 8, 9]]`.

# %% [markdown]
# **Question 62:** Print the number of dimensions of `matrix` using the `.ndim` attribute.

# %% [markdown]
# **Question 63:** Print the shape of `matrix` using the `.shape` attribute.

# %% [markdown]
# **Question 64:** Access the element in the 2nd row, 3rd column of `matrix`.

# %% [markdown]
# **Question 65:** Slice `matrix` to extract the entire 1st row.

# %% [markdown]
# **Question 66:** Slice `matrix` to extract the entire 2nd column.

# %% [markdown]
# **Question 67:** Slice `matrix` to extract a 2x2 sub-matrix from the top-left corner.

# %% [markdown]
# **Question 68:** Transpose `matrix` using the `.T` attribute.

# %% [markdown]
# **Question 69:** Create a 1D array `vec` equal to `[10, 20, 30]`. Compute the dot product of `matrix` and `vec` using `np.dot()` or `@`.

# %% [markdown]
# **Question 70:** What is the shape of the resulting dot product from Question 69?

# %% [markdown]
# **Question 71:** Reshape `vec` into a column vector of shape `(3, 1)` using `.reshape()`.

# %% [markdown]
# **Question 72:** Generate a 3x3 matrix of random numbers from a standard normal distribution using `np.random.randn()`.

# %% [markdown]
# **Question 73:** Set the random seed to `42` using `np.random.seed(42)` and generate another 3x3 random matrix.

# %%
np.random.seed(42)

# %% [markdown]
# **Question 74:** Find the maximum value in the random matrix from Question 73.

# %% [markdown]
# **Question 75:** Find the indices of the maximum value in the random matrix using `np.argmax()`.

# %% [markdown]
# ### Section 7: Data Visualization with Matplotlib (Questions 76-85)

# %% [markdown]
# **Question 76:** Import `matplotlib.pyplot` as `plt`.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Question 77:** Generate a random array `x` of size 50 and another random array `y` of size 50.

# %% [markdown]
# **Question 78:** Create a basic scatter plot of `x` versus `y`.

# %% [markdown]
# **Question 79:** Recreate the scatter plot but use red circle markers (`'ro'`).

# %% [markdown]
# **Question 80:** Add an x-axis label 'Predictor X' and y-axis label 'Response Y' to your plot.

# %% [markdown]
# **Question 81:** Add the title 'Random Scatter Plot' to your figure.

# %% [markdown]
# **Question 82:** Generate a sequence `x_seq` from -5 to 5 using `np.linspace` (100 points).

# %% [markdown]
# **Question 83:** Calculate `y_seq = x_seq**2`. Plot `x_seq` vs `y_seq` as a line plot.

# %% [markdown]
# **Question 84:** Create a figure with 2 subplots side-by-side using `plt.subplots(1, 2)`. Plot the scatter plot in the first and the line plot in the second.

# %% [markdown]
# **Question 85:** Save your plot as 'my_plot.png' using `plt.savefig()`.

# %% [markdown]
# ### Section 8: Implementing Statistical Concepts in Code (Questions 86-100)

# %% [markdown]
# **Question 86:** Let `y_true = np.array([2.5, 0.0, 2, 8])` and `y_pred = np.array([3.0, -0.5, 2, 7.5])`. Calculate the residuals (errors).

# %%
y_true = np.array([2.5, 0.0, 2, 8])
y_pred = np.array([3.0, -0.5, 2, 7.5])

# %% [markdown]
# **Question 87:** Calculate the squared residuals from Question 86.

# %% [markdown]
# **Question 88:** Write a Python function `calculate_mse(y_true, y_pred)` that returns the Mean Squared Error. Test it on the arrays from Q86.

# %%
def calculate_mse(y_true, y_pred):
    # your code here
    pass

# %% [markdown]
# **Question 89:** Given a test point `x_0 = np.array([5, 5])` and a training point `x_train = np.array([2, 1])`, calculate the Euclidean distance between them.

# %%
x_0 = np.array([5, 5])
x_train = np.array([2, 1])

# %% [markdown]
# **Question 90:** Create an array of 5 training points `X_train = np.array([[1,1], [2,2], [8,8], [9,9], [1,2]])`. Write code to find the Euclidean distance from `x_0 = np.array([0,0])` to each point in `X_train`.

# %% [markdown]
# **Question 91:** Sort the distances from Question 90 in ascending order and print the indices of the sorted array using `np.argsort()`.

# %% [markdown]
# **Question 92:** Assume the classes for `X_train` are `y_train = np.array([0, 0, 1, 1, 0])`. Find the class of the single closest neighbor (K=1) to `x_0` based on your `argsort` result.

# %% [markdown]
# **Question 93:** Write a small loop or use array slicing to find the classes of the `K=3` nearest neighbors to `x_0`.

# %% [markdown]
# **Question 94:** For the 3 nearest neighbors found in Question 93, determine the majority class (this is your KNN prediction for K=3).

# %% [markdown]
# **Question 95:** Simulate irreducible error: Generate `x = np.linspace(0, 10, 50)`. Let `f_x = 2 * x + 5`. Create `y` by adding standard normal noise `epsilon` to `f_x`. Plot `x` vs `y`.

# %% [markdown]
# **Question 96:** On the same plot from Q95, draw the 'true' line `f_x` in black. Notice how the data points bounce around this true line due to `epsilon`.

# %% [markdown]
# **Question 97:** Assume we fit a model that predicts `y_hat = 2.2 * x + 4.5`. Calculate the Training MSE.

# %% [markdown]
# **Question 98:** Generate a brand new set of 50 points using the exact same process as Q95 (this is your test set).

# %% [markdown]
# **Question 99:** Calculate the Test MSE of the `y_hat` model on this new test set.

# %% [markdown]
# **Question 100:** If we fit a perfect line `y_hat = f_x = 2 * x + 5`, would the Test MSE be zero? Why or why not? Write your conceptual answer below or as a print statement.

# %%
print('Your answer here.')
