# %% [markdown]
# # 🏋️ Practice Problems: 01_FOUNDATIONS
# ## ML Landscape & Statistical Learning
#
# **Topics covered**: supervised vs unsupervised, train/test split, overfitting, bias-variance, cross-validation
#
# This notebook contains 100 practice problems:
# - 🧠 **Conceptual** (Q1-Q35): Explain, compare, true/false with justification
# - 📐 **Theoretical** (Q36-Q65): Derivations, proofs, mathematical formulations
# - 💻 **Practical** (Q66-Q100): Code implementations, data analysis, plotting
#
# **Difficulty levels**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)
#
# **Datasets**: Auto.csv, housing data (HOML3)

# %% [markdown]
# ## 🧠 Conceptual Problems (Q1 - Q35)

# %% [markdown]
# **Q1.** [⭐] What is supervised learning? Give 3 examples.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Supervised = labeled data.
#
# </details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain why we split data into training and test sets. What goes wrong if we skip this?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Overfitting, generalization gap.
#
# </details>

# %% [markdown]
# **Q3.** [⭐⭐] What is the bias-variance tradeoff? Describe a high-bias model and a high-variance model.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Bias=underfitting, Variance=overfitting.
#
# </details>

# %% [markdown]
# **Q4.** [⭐] True or False: A model with 100% accuracy on training data is always good. Justify.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Consider overfitting to noise.
#
# </details>

# %% [markdown]
# **Q5.** [⭐⭐⭐] What is a learning curve? How do you use it to diagnose underfitting vs overfitting?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Plot train and validation error vs training set size.
#
# </details>

# %% [markdown]
# **Q6-Q35.** Fill in with additional conceptual problems following the same structure.

# %% [markdown]
# ## 📐 Theoretical Problems (Q36 - Q65)

# %% [markdown]
# **Q36.** [⭐] Derive training error = (# misclassifications) / n. When is this a good metric?

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# It's not good for imbalanced data.
#
# </details>

# %% [markdown]
# **Q37.** [⭐⭐] Prove E[test error] = bias² + variance + irreducible error. Explain each term.

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Expand E[(Y - f_hat(X))²].
#
# </details>

# %% [markdown]
# **Q38-Q65.** Fill in with additional theoretical problems (proofs, derivations).

# %% [markdown]
# ## 💻 Practical Problems (Q66 - Q100)

# %% [markdown]
# **Q66.** [⭐] Load Auto.csv. Split 80% train, 20% test. Use seed=42.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use train_test_split(test_size=0.2, random_state=42).
#
# </details>

# %% [markdown]
# **Q67.** [⭐⭐] Fit linear regression to predict MPG from weight. Report train and test MSE. Is there overfitting?

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# MSE = mean((y - y_pred)²).
#
# </details>

# %% [markdown]
# **Q68.** [⭐⭐] Create a learning curve: plot train/test MSE vs training set size (10%, 25%, 50%, 75%, 100%). What does it reveal?

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use 5-fold CV for stability.
#
# </details>

# %% [markdown]
# **Q69-Q100.** Fill in with additional practical problems (coding, analysis).

# %% [markdown]
# ---
#
# ## 📝 How to use this notebook:
#
# 1. **Work through problems in order** within each section
# 2. **Use hints liberally** — they point you in the right direction
# 3. **Compare with solutions** after completing (once posted)
# 4. **Challenge yourself** — skip to harder problems (⭐⭐⭐) if you're comfortable
# 5. **Revisit regularly** — revisiting problems helps consolidate learning
#
# Good luck! 🚀
