# %% [markdown]
# # 🏋️ Custom Practice: 01 The Machine Learning Landscape
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Setup

# %% [markdown]
# **✨ Task:** Practice Exercise for **Setup**:
# Implement a small, self-contained example demonstrating the core concept of Setup. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Code example 1-1

# %% [markdown]
# **✨ Task:** Practice Exercise for **Code example 1-1**:
# Implement a small, self-contained example demonstrating the core concept of Code example 1-1. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Generating the data and figures — please skip

# %% [markdown]
# **✨ Task:** Practice Exercise for **Generating the data and figures — please skip**:
# Implement a small, self-contained example demonstrating the core concept of Generating the data and figures — please skip. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Load and prepare Life satisfaction data

# %% [markdown]
# **✨ Task:** Practice Exercise for **Load and prepare Life satisfaction data**:
# Implement a small, self-contained example demonstrating the core concept of Load and prepare Life satisfaction data. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Exercise Solutions

# %% [markdown]
# **✨ Task:** Practice Exercise for **Exercise Solutions**:
# Implement a small, self-contained example demonstrating the core concept of Exercise Solutions. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
