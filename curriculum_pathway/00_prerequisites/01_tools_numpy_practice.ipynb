# %% [markdown]
# # 🏋️ Custom Practice: 01 Tools Numpy
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Creating Arrays

# %% [markdown]
# **✨ Task:** Initialize three different types of arrays: a 1D list of your favorite numbers, a 3x3 matrix of zeros, and a 2x4 matrix of ones. Check their shapes.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `np.zeros`

# %% [markdown]
# **✨ Task:** Create a 5x5 matrix entirely filled with zeros. What is its default data type? Print the dtype.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Some vocabulary

# %% [markdown]
# **✨ Task:** In a markdown cell, define 'rank', 'shape', and 'axis' in your own words.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## N-dimensional arrays

# %% [markdown]
# **✨ Task:** Create a 3D array (tensor) of shape (2, 3, 4) using arbitrary numbers.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Array type

# %% [markdown]
# **✨ Task:** Create an array of floats, then convert it to an array of integers using astype().

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `np.ones`

# %% [markdown]
# **✨ Task:** Create a 4x4 matrix of ones. Multiply the entire matrix by 7 so it becomes a matrix of 7s.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `np.full`

# %% [markdown]
# **✨ Task:** Use np.full to create a 3x5 matrix filled with the value 3.14.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `np.empty`

# %% [markdown]
# **✨ Task:** Allocate an empty array of size 2x2. Print it to see the uninitialized memory values.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## np.array

# %% [markdown]
# **✨ Task:** Convert the standard Python list `[[1, 2], [3, 4]]` into a NumPy array.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `np.arange`

# %% [markdown]
# **✨ Task:** Generate an array of even numbers from 10 to 50 using np.arange.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `np.linspace`

# %% [markdown]
# **✨ Task:** Generate 100 evenly spaced points between 0 and 1 using np.linspace. This is useful for plotting!

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `np.rand` and `np.randn`

# %% [markdown]
# **✨ Task:** Practice Exercise for **`np.rand` and `np.randn`**:
# Implement a small, self-contained example demonstrating the core concept of `np.rand` and `np.randn`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## np.fromfunction

# %% [markdown]
# **✨ Task:** Create a 5x5 matrix where the value at (i, j) is equal to i + j.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Array data

# %% [markdown]
# **✨ Task:** Access the underlying data buffer of a 1D array. (Advanced, just verify it exists).

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `data` buffer

# %% [markdown]
# **✨ Task:** Practice Exercise for **`data` buffer**:
# Implement a small, self-contained example demonstrating the core concept of `data` buffer. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Reshaping an array

# %% [markdown]
# **✨ Task:** Create a 1D array of 24 elements. Reshape it into a 3D array of shape (2, 3, 4).

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `reshape`

# %% [markdown]
# **✨ Task:** Take a 4x4 matrix and reshape it into a 16-element 1D array.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `ravel`

# %% [markdown]
# **✨ Task:** Flatten a 2x2 matrix using ravel(). Does this return a copy or a view?

# %%
# YOUR CODE HERE

# %% [markdown]
# # Arithmetic operations

# %% [markdown]
# **✨ Task:** Create two 3x3 matrices. Add them, multiply them element-wise, and subtract one from the other.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Broadcasting

# %% [markdown]
# **✨ Task:** Create a 3x3 matrix and a 1D array of 3 elements. Add the 1D array to the matrix. Explain what happens in a comment.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Second rule

# %% [markdown]
# **✨ Task:** Demonstrate broadcasting a shape (3,1) array with a shape (1,3) array. What is the resulting shape?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Third rule

# %% [markdown]
# **✨ Task:** Practice Exercise for **Third rule**:
# Implement a small, self-contained example demonstrating the core concept of Third rule. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Upcasting

# %% [markdown]
# **✨ Task:** Add an array of integers to an array of floats. Verify the resulting dtype.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Conditional operators

# %% [markdown]
# **✨ Task:** Create a 1D array from 1 to 10. Write a boolean condition to find all elements greater than 5.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Mathematical and statistical functions

# %% [markdown]
# **✨ Task:** Calculate the mean, sum, and standard deviation of a 5x5 random matrix.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Universal functions

# %% [markdown]
# **✨ Task:** Practice Exercise for **Universal functions**:
# Implement a small, self-contained example demonstrating the core concept of Universal functions. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Binary ufuncs

# %% [markdown]
# **✨ Task:** Practice Exercise for **Binary ufuncs**:
# Implement a small, self-contained example demonstrating the core concept of Binary ufuncs. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Array indexing

# %% [markdown]
# **✨ Task:** Create a 1D array of 10 elements. Slice it to get the last 3 elements.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Differences with regular python arrays

# %% [markdown]
# **✨ Task:** Practice Exercise for **Differences with regular python arrays**:
# Implement a small, self-contained example demonstrating the core concept of Differences with regular python arrays. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Multidimensional arrays

# %% [markdown]
# **✨ Task:** From a 4x4 matrix, extract the 2x2 sub-matrix in the top-right corner.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Fancy indexing

# %% [markdown]
# **✨ Task:** Use an array of specific indices `[0, 2, 4]` to extract elements from a 1D array of size 10.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Higher dimensions

# %% [markdown]
# **✨ Task:** Practice Exercise for **Higher dimensions**:
# Implement a small, self-contained example demonstrating the core concept of Higher dimensions. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Ellipsis (`...`)

# %% [markdown]
# **✨ Task:** Practice Exercise for **Ellipsis (`...`)**:
# Implement a small, self-contained example demonstrating the core concept of Ellipsis (`...`). Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Boolean indexing

# %% [markdown]
# **✨ Task:** Given an array of random integers between 1 and 20, extract only the even numbers using boolean indexing.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `np.ix_`

# %% [markdown]
# **✨ Task:** Practice Exercise for **`np.ix_`**:
# Implement a small, self-contained example demonstrating the core concept of `np.ix_`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Iterating

# %% [markdown]
# **✨ Task:** Practice Exercise for **Iterating**:
# Implement a small, self-contained example demonstrating the core concept of Iterating. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Stacking arrays

# %% [markdown]
# **✨ Task:** Create two 2x2 matrices. Stack them vertically, then stack them horizontally.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `vstack`

# %% [markdown]
# **✨ Task:** Practice Exercise for **`vstack`**:
# Implement a small, self-contained example demonstrating the core concept of `vstack`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `concatenate`

# %% [markdown]
# **✨ Task:** Practice Exercise for **`concatenate`**:
# Implement a small, self-contained example demonstrating the core concept of `concatenate`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `stack`

# %% [markdown]
# **✨ Task:** Practice Exercise for **`stack`**:
# Implement a small, self-contained example demonstrating the core concept of `stack`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Splitting arrays

# %% [markdown]
# **✨ Task:** Create an array of size 10. Split it into 3 unequal parts.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Transposing arrays

# %% [markdown]
# **✨ Task:** Create a 3x2 matrix. Transpose it to a 2x3 matrix. Check its shape.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Linear algebra

# %% [markdown]
# **✨ Task:** Create a 2x2 matrix and calculate its dot product with a 2x1 vector.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Matrix multiplication

# %% [markdown]
# **✨ Task:** Multiply a 3x2 matrix with a 2x4 matrix using the `@` operator.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Matrix inverse and pseudo-inverse

# %% [markdown]
# **✨ Task:** Calculate the inverse of a 2x2 square matrix using np.linalg.inv.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Identity matrix

# %% [markdown]
# **✨ Task:** Practice Exercise for **Identity matrix**:
# Implement a small, self-contained example demonstrating the core concept of Identity matrix. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## QR decomposition

# %% [markdown]
# **✨ Task:** Practice Exercise for **QR decomposition**:
# Implement a small, self-contained example demonstrating the core concept of QR decomposition. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Determinant

# %% [markdown]
# **✨ Task:** Practice Exercise for **Determinant**:
# Implement a small, self-contained example demonstrating the core concept of Determinant. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Eigenvalues and eigenvectors

# %% [markdown]
# **✨ Task:** Practice Exercise for **Eigenvalues and eigenvectors**:
# Implement a small, self-contained example demonstrating the core concept of Eigenvalues and eigenvectors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Singular Value Decomposition

# %% [markdown]
# **✨ Task:** Practice Exercise for **Singular Value Decomposition**:
# Implement a small, self-contained example demonstrating the core concept of Singular Value Decomposition. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Diagonal and trace

# %% [markdown]
# **✨ Task:** Practice Exercise for **Diagonal and trace**:
# Implement a small, self-contained example demonstrating the core concept of Diagonal and trace. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Solving a system of linear scalar equations

# %% [markdown]
# **✨ Task:** Solve the system: 2x + 3y = 8 and x - y = 1 using np.linalg.solve.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Vectorization

# %% [markdown]
# **✨ Task:** Practice Exercise for **Vectorization**:
# Implement a small, self-contained example demonstrating the core concept of Vectorization. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Saving and loading

# %% [markdown]
# **✨ Task:** Practice Exercise for **Saving and loading**:
# Implement a small, self-contained example demonstrating the core concept of Saving and loading. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Text format

# %% [markdown]
# **✨ Task:** Practice Exercise for **Text format**:
# Implement a small, self-contained example demonstrating the core concept of Text format. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Zipped `.npz` format

# %% [markdown]
# **✨ Task:** Practice Exercise for **Zipped `.npz` format**:
# Implement a small, self-contained example demonstrating the core concept of Zipped `.npz` format. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # What's next?

# %% [markdown]
# **✨ Task:** Practice Exercise for **What's next?**:
# Implement a small, self-contained example demonstrating the core concept of What's next?. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
