# %% [markdown]
# # 🏋️ Custom Practice: 12 Krohn Algos And Data Structures
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Algorithms & Data Structures

# %% [markdown]
# **✨ Task:** Practice Exercise for **Algorithms & Data Structures**:
# Implement a small, self-contained example demonstrating the core concept of Algorithms & Data Structures. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Segment 1: Intro to Data Structures & Algorithms

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 1: Intro to Data Structures & Algorithms**:
# Implement a small, self-contained example demonstrating the core concept of Segment 1: Intro to Data Structures & Algorithms. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### "Big O" Notation

# %% [markdown]
# **✨ Task:** Practice Exercise for **"Big O" Notation**:
# Implement a small, self-contained example demonstrating the core concept of "Big O" Notation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Constant Time

# %% [markdown]
# **✨ Task:** Practice Exercise for **Constant Time**:
# Implement a small, self-contained example demonstrating the core concept of Constant Time. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Linear Time

# %% [markdown]
# **✨ Task:** Practice Exercise for **Linear Time**:
# Implement a small, self-contained example demonstrating the core concept of Linear Time. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Polynomial Time

# %% [markdown]
# **✨ Task:** Practice Exercise for **Polynomial Time**:
# Implement a small, self-contained example demonstrating the core concept of Polynomial Time. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 2: Lists and Dictionaries

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 2: Lists and Dictionaries**:
# Implement a small, self-contained example demonstrating the core concept of Segment 2: Lists and Dictionaries. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### List-Based Data Structures

# %% [markdown]
# **✨ Task:** Practice Exercise for **List-Based Data Structures**:
# Implement a small, self-contained example demonstrating the core concept of List-Based Data Structures. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Lists

# %% [markdown]
# **✨ Task:** Practice Exercise for **Lists**:
# Implement a small, self-contained example demonstrating the core concept of Lists. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Arrays

# %% [markdown]
# **✨ Task:** Practice Exercise for **Arrays**:
# Implement a small, self-contained example demonstrating the core concept of Arrays. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Stacks

# %% [markdown]
# **✨ Task:** Practice Exercise for **Stacks**:
# Implement a small, self-contained example demonstrating the core concept of Stacks. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Searching and Sorting

# %% [markdown]
# **✨ Task:** Practice Exercise for **Searching and Sorting**:
# Implement a small, self-contained example demonstrating the core concept of Searching and Sorting. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Binary Search

# %% [markdown]
# **✨ Task:** Practice Exercise for **Binary Search**:
# Implement a small, self-contained example demonstrating the core concept of Binary Search. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Bubble Sort

# %% [markdown]
# **✨ Task:** Practice Exercise for **Bubble Sort**:
# Implement a small, self-contained example demonstrating the core concept of Bubble Sort. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Merge Sort

# %% [markdown]
# **✨ Task:** Practice Exercise for **Merge Sort**:
# Implement a small, self-contained example demonstrating the core concept of Merge Sort. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Quick Sort

# %% [markdown]
# **✨ Task:** Practice Exercise for **Quick Sort**:
# Implement a small, self-contained example demonstrating the core concept of Quick Sort. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Set-Based Data Structures: Maps/Dictionaries

# %% [markdown]
# **✨ Task:** Practice Exercise for **Set-Based Data Structures: Maps/Dictionaries**:
# Implement a small, self-contained example demonstrating the core concept of Set-Based Data Structures: Maps/Dictionaries. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Hashing

# %% [markdown]
# **✨ Task:** Practice Exercise for **Hashing**:
# Implement a small, self-contained example demonstrating the core concept of Hashing. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Collisions

# %% [markdown]
# **✨ Task:** Practice Exercise for **Collisions**:
# Implement a small, self-contained example demonstrating the core concept of Collisions. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Hash Maps

# %% [markdown]
# **✨ Task:** Practice Exercise for **Hash Maps**:
# Implement a small, self-contained example demonstrating the core concept of Hash Maps. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### String Keys

# %% [markdown]
# **✨ Task:** Practice Exercise for **String Keys**:
# Implement a small, self-contained example demonstrating the core concept of String Keys. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 3: Trees and Graphs

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 3: Trees and Graphs**:
# Implement a small, self-contained example demonstrating the core concept of Segment 3: Trees and Graphs. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Decision Trees

# %% [markdown]
# **✨ Task:** Practice Exercise for **Decision Trees**:
# Implement a small, self-contained example demonstrating the core concept of Decision Trees. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Random Forests

# %% [markdown]
# **✨ Task:** Practice Exercise for **Random Forests**:
# Implement a small, self-contained example demonstrating the core concept of Random Forests. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Gradient-Boosted Trees

# %% [markdown]
# **✨ Task:** Practice Exercise for **Gradient-Boosted Trees**:
# Implement a small, self-contained example demonstrating the core concept of Gradient-Boosted Trees. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
