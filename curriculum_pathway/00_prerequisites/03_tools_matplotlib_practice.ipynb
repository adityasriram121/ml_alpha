# %% [markdown]
# # 🏋️ Custom Practice: 03 Tools Matplotlib
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Plotting your first graph

# %% [markdown]
# **✨ Task:** Generate a simple line plot of y = x^2 for x ranging from -10 to 10.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Line style and color

# %% [markdown]
# **✨ Task:** Modify your previous plot: make the line dashed, red, and add a thickness of 2.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Saving a figure

# %% [markdown]
# **✨ Task:** Save the plot you just created as a 'my_plot.png' file in the current directory.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Subplots

# %% [markdown]
# **✨ Task:** Create a figure with 2 subplots side-by-side. Plot y=x in the first, and y=x^3 in the second.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Multiple figures

# %% [markdown]
# **✨ Task:** Create two entirely separate figure windows and plot different functions in each.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Pyplot's state machine: implicit *vs* explicit

# %% [markdown]
# **✨ Task:** Practice Exercise for **Pyplot's state machine: implicit *vs* explicit**:
# Implement a small, self-contained example demonstrating the core concept of Pyplot's state machine: implicit *vs* explicit. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Drawing text

# %% [markdown]
# **✨ Task:** Practice Exercise for **Drawing text**:
# Implement a small, self-contained example demonstrating the core concept of Drawing text. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Legends

# %% [markdown]
# **✨ Task:** Plot y=sin(x) and y=cos(x) on the same graph. Add a legend in the top right corner.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Non-linear scales

# %% [markdown]
# **✨ Task:** Practice Exercise for **Non-linear scales**:
# Implement a small, self-contained example demonstrating the core concept of Non-linear scales. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Ticks and tickers

# %% [markdown]
# **✨ Task:** Practice Exercise for **Ticks and tickers**:
# Implement a small, self-contained example demonstrating the core concept of Ticks and tickers. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Polar projection

# %% [markdown]
# **✨ Task:** Practice Exercise for **Polar projection**:
# Implement a small, self-contained example demonstrating the core concept of Polar projection. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # 3D projection

# %% [markdown]
# **✨ Task:** Create a 3D scatter plot of random points. (Requires mpl_toolkits.mplot3d).

# %%
# YOUR CODE HERE

# %% [markdown]
# # Scatter plot

# %% [markdown]
# **✨ Task:** Practice Exercise for **Scatter plot**:
# Implement a small, self-contained example demonstrating the core concept of Scatter plot. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Lines

# %% [markdown]
# **✨ Task:** Practice Exercise for **Lines**:
# Implement a small, self-contained example demonstrating the core concept of Lines. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Histograms

# %% [markdown]
# **✨ Task:** Generate 1000 random normal variables and plot their distribution using a histogram with 30 bins.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Images

# %% [markdown]
# **✨ Task:** Practice Exercise for **Images**:
# Implement a small, self-contained example demonstrating the core concept of Images. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Animations

# %% [markdown]
# **✨ Task:** Practice Exercise for **Animations**:
# Implement a small, self-contained example demonstrating the core concept of Animations. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Saving animations to video files

# %% [markdown]
# **✨ Task:** Practice Exercise for **Saving animations to video files**:
# Implement a small, self-contained example demonstrating the core concept of Saving animations to video files. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # What's next?

# %% [markdown]
# **✨ Task:** Practice Exercise for **What's next?**:
# Implement a small, self-contained example demonstrating the core concept of What's next?. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
