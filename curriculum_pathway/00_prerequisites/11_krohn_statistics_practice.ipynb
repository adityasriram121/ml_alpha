# %% [markdown]
# # 🏋️ Custom Practice: 11 Krohn Statistics
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Intro to Statistics

# %% [markdown]
# **✨ Task:** Practice Exercise for **Intro to Statistics**:
# Implement a small, self-contained example demonstrating the core concept of Intro to Statistics. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 1: Frequentist Statistics

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 1: Frequentist Statistics**:
# Implement a small, self-contained example demonstrating the core concept of Segment 1: Frequentist Statistics. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Measures of Central Tendency

# %% [markdown]
# **✨ Task:** Practice Exercise for **Measures of Central Tendency**:
# Implement a small, self-contained example demonstrating the core concept of Measures of Central Tendency. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Mean

# %% [markdown]
# **✨ Task:** Practice Exercise for **Mean**:
# Implement a small, self-contained example demonstrating the core concept of Mean. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Median

# %% [markdown]
# **✨ Task:** Practice Exercise for **Median**:
# Implement a small, self-contained example demonstrating the core concept of Median. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Measures of Dispersion

# %% [markdown]
# **✨ Task:** Practice Exercise for **Measures of Dispersion**:
# Implement a small, self-contained example demonstrating the core concept of Measures of Dispersion. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Variance

# %% [markdown]
# **✨ Task:** Practice Exercise for **Variance**:
# Implement a small, self-contained example demonstrating the core concept of Variance. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Standard Deviation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Standard Deviation**:
# Implement a small, self-contained example demonstrating the core concept of Standard Deviation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Standard Error

# %% [markdown]
# **✨ Task:** Practice Exercise for **Standard Error**:
# Implement a small, self-contained example demonstrating the core concept of Standard Error. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Gaussian Distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Gaussian Distribution**:
# Implement a small, self-contained example demonstrating the core concept of Gaussian Distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### The Central Limit Theorem

# %% [markdown]
# **✨ Task:** Practice Exercise for **The Central Limit Theorem**:
# Implement a small, self-contained example demonstrating the core concept of The Central Limit Theorem. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Sampling from a skewed distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Sampling from a skewed distribution**:
# Implement a small, self-contained example demonstrating the core concept of Sampling from a skewed distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Sampling from a multimodal distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Sampling from a multimodal distribution**:
# Implement a small, self-contained example demonstrating the core concept of Sampling from a multimodal distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Sampling from uniform

# %% [markdown]
# **✨ Task:** Practice Exercise for **Sampling from uniform**:
# Implement a small, self-contained example demonstrating the core concept of Sampling from uniform. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### z-scores

# %% [markdown]
# **✨ Task:** Practice Exercise for **z-scores**:
# Implement a small, self-contained example demonstrating the core concept of z-scores. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### *p*-values

# %% [markdown]
# **✨ Task:** Practice Exercise for ***p*-values**:
# Implement a small, self-contained example demonstrating the core concept of *p*-values. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Comparing Means with *t*-tests

# %% [markdown]
# **✨ Task:** Practice Exercise for **Comparing Means with *t*-tests**:
# Implement a small, self-contained example demonstrating the core concept of Comparing Means with *t*-tests. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Student's Single-Sample *t*-test

# %% [markdown]
# **✨ Task:** Practice Exercise for **Student's Single-Sample *t*-test**:
# Implement a small, self-contained example demonstrating the core concept of Student's Single-Sample *t*-test. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Welch's Independent *t*-test

# %% [markdown]
# **✨ Task:** Practice Exercise for **Welch's Independent *t*-test**:
# Implement a small, self-contained example demonstrating the core concept of Welch's Independent *t*-test. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Student's Paired *t*-test

# %% [markdown]
# **✨ Task:** Practice Exercise for **Student's Paired *t*-test**:
# Implement a small, self-contained example demonstrating the core concept of Student's Paired *t*-test. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Machine Learning Examples

# %% [markdown]
# **✨ Task:** Practice Exercise for **Machine Learning Examples**:
# Implement a small, self-contained example demonstrating the core concept of Machine Learning Examples. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Confidence Intervals

# %% [markdown]
# **✨ Task:** Practice Exercise for **Confidence Intervals**:
# Implement a small, self-contained example demonstrating the core concept of Confidence Intervals. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### ANOVA: Analysis of Variance

# %% [markdown]
# **✨ Task:** Practice Exercise for **ANOVA: Analysis of Variance**:
# Implement a small, self-contained example demonstrating the core concept of ANOVA: Analysis of Variance. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Pearson Correlation Coefficient

# %% [markdown]
# **✨ Task:** Practice Exercise for **Pearson Correlation Coefficient**:
# Implement a small, self-contained example demonstrating the core concept of Pearson Correlation Coefficient. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### The Coefficient of Determination

# %% [markdown]
# **✨ Task:** Practice Exercise for **The Coefficient of Determination**:
# Implement a small, self-contained example demonstrating the core concept of The Coefficient of Determination. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Correlation vs Causation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Correlation vs Causation**:
# Implement a small, self-contained example demonstrating the core concept of Correlation vs Causation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Correcting for Multiple Comparisons

# %% [markdown]
# **✨ Task:** Practice Exercise for **Correcting for Multiple Comparisons**:
# Implement a small, self-contained example demonstrating the core concept of Correcting for Multiple Comparisons. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 2: Regression

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 2: Regression**:
# Implement a small, self-contained example demonstrating the core concept of Segment 2: Regression. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Linear Least Squares for Fitting a Line to Points on a Cartesian Plane

# %% [markdown]
# **✨ Task:** Practice Exercise for **Linear Least Squares for Fitting a Line to Points on a Cartesian Plane**:
# Implement a small, self-contained example demonstrating the core concept of Linear Least Squares for Fitting a Line to Points on a Cartesian Plane. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Ordinary Least Squares

# %% [markdown]
# **✨ Task:** Practice Exercise for **Ordinary Least Squares**:
# Implement a small, self-contained example demonstrating the core concept of Ordinary Least Squares. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# **✨ Task:** Practice Exercise for **Logistic Regression**:
# Implement a small, self-contained example demonstrating the core concept of Logistic Regression. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 3: Bayesian Statistics

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 3: Bayesian Statistics**:
# Implement a small, self-contained example demonstrating the core concept of Segment 3: Bayesian Statistics. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Bayes' Theorem

# %% [markdown]
# **✨ Task:** Practice Exercise for **Bayes' Theorem**:
# Implement a small, self-contained example demonstrating the core concept of Bayes' Theorem. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
