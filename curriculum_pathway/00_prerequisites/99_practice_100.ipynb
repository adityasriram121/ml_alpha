# %% [markdown]
# # 🏋️ Practice Problems: 00_PREREQUISITES
# ## Data & Python Foundations
#
# **Topics covered**: NumPy, pandas, matplotlib, linear algebra, calculus, probability, statistics, algorithms
#
# This notebook contains 100 practice problems:
# - 🧠 **Conceptual** (Q1-Q35): Explain, compare, true/false with justification
# - 📐 **Theoretical** (Q36-Q65): Derivations, proofs, mathematical formulations
# - 💻 **Practical** (Q66-Q100): Code implementations, data analysis, plotting
#
# **Difficulty levels**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)
#
# **Datasets**: Auto.csv

# %% [markdown]
# ## 🧠 Conceptual Problems (Q1 - Q35)

# %% [markdown]
# **Q1.** [⭐⭐] Explain the difference between NumPy arrays and Python lists. Why would you choose a NumPy array for numerical computation?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Think about memory layout, speed, and vectorization.
#
# </details>

# %% [markdown]
# **Q2.** [⭐⭐] What is a pandas DataFrame? How is it different from a NumPy 2D array?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Consider column names, heterogeneous dtypes, and indexing.
#
# </details>

# %% [markdown]
# **Q3.** [⭐] True or False: A matplotlib Figure is a container for one or more Axes. Justify your answer.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Review the Figure vs Axes distinction.
#
# </details>

# %% [markdown]
# **Q4.** [⭐⭐⭐] Explain what a matrix inverse is and why it's important in linear algebra. When does a matrix NOT have an inverse?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Think about determinants and singular matrices.
#
# </details>

# %% [markdown]
# **Q5.** [⭐⭐] What is the derivative of a function? Explain it both graphically and mathematically.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Connect slope, rate of change, and limits.
#
# </details>

# %% [markdown]
# **Q6.** [⭐] In NumPy, what is broadcasting? Give a concrete example.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Broadcasting allows operations on arrays of different shapes.
#
# </details>

# %% [markdown]
# **Q7.** [⭐⭐] Explain the difference between .loc[] and .iloc[] in pandas.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# .loc[] is label-based, .iloc[] is position-based.
#
# </details>

# %% [markdown]
# **Q8.** [⭐⭐⭐] What is a probability distribution? Name and describe three common distributions.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Normal, binomial, uniform, exponential, etc.
#
# </details>

# %% [markdown]
# **Q9.** [⭐] What is a time complexity? Why does O(n log n) matter for algorithms?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# It measures how runtime scales with input size.
#
# </details>

# %% [markdown]
# **Q10.** [⭐⭐] What is eigenvalue and eigenvector? What do they represent geometrically?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# They represent directions and scaling factors in linear transformations.
#
# </details>

# %% [markdown]
# **Q11-Q35.** Fill in with additional conceptual problems following the same pattern. Refer to the curriculum notebooks for topics.

# %% [markdown]
# ## 📐 Theoretical Problems (Q36 - Q65)

# %% [markdown]
# **Q36.** [⭐] Derive the formula for the mean (average) of a dataset. Show it's the 'center of mass'.

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Start with sum all values, divide by count.
#
# </details>

# %% [markdown]
# **Q37.** [⭐⭐] Prove that Var(X) = E[X²] - (E[X])². (Expand the definition of variance.)

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Var(X) = E[(X - μ)²]. Expand the square.
#
# </details>

# %% [markdown]
# **Q38.** [⭐⭐⭐] Derive the chain rule for derivatives: d/dx[f(g(x))] = f'(g(x)) * g'(x). Explain why.

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use limits and the definition of derivative.
#
# </details>

# %% [markdown]
# **Q39.** [⭐] Prove that the determinant of [[a, b], [c, d]] is ad - bc using cofactor expansion.

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use the 2x2 formula directly.
#
# </details>

# %% [markdown]
# **Q40.** [⭐⭐] Derive P(A and B) = P(A) * P(B) for independent events. Explain the independence assumption.

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Think about counting outcomes.
#
# </details>

# %% [markdown]
# **Q41-Q65.** Fill in with additional theoretical problems (proofs, derivations) following the same pattern.

# %% [markdown]
# ## 💻 Practical Problems (Q66 - Q100)

# %% [markdown]
# **Q66.** [⭐] Create a NumPy array of 1000 random numbers between 0 and 1. Compute mean, std, min, max, median.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use np.random.rand(), np.mean(), np.std(), np.min(), np.max(), np.median().
#
# </details>

# %% [markdown]
# **Q67.** [⭐⭐] Load Auto.csv. Filter rows where MPG > 20 AND cylinders <= 4. What columns exist? Show summary statistics.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use pd.read_csv(), boolean indexing, .describe().
#
# </details>

# %% [markdown]
# **Q68.** [⭐⭐] Create a 2x2 subplot: (1) scatter weight vs mpg, (2) histogram of mpg, (3) bar chart of cylinder counts, (4) box plot by cylinders.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use plt.subplot() or plt.subplots().
#
# </details>

# %% [markdown]
# **Q69.** [⭐] Multiply two 3x3 matrices by hand, verify with np.matmul() and the @ operator.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Matrix multiplication: (i,j) = sum_k A[i,k] * B[k,j].
#
# </details>

# %% [markdown]
# **Q70-Q100.** Fill in with additional practical problems (coding, analysis, visualization) following the same pattern.

# %% [markdown]
# ---
#
# ## 📝 How to use this notebook:
#
# 1. **Work through problems in order** within each section
# 2. **Use hints liberally** — they point you in the right direction
# 3. **Compare with solutions** after completing (once posted)
# 4. **Challenge yourself** — skip to harder problems (⭐⭐⭐) if you're comfortable
# 5. **Revisit regularly** — revisiting problems helps consolidate learning
#
# Good luck! 🚀

# %% [markdown]
# ### Appendix: Useful Imports
#
# ```python
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sklearn import *
# ```
