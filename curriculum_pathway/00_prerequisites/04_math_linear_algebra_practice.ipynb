# %% [markdown]
# # 🏋️ Custom Practice: 04 Math Linear Algebra
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Vectors

# %% [markdown]
# **✨ Task:** Practice Exercise for **Vectors**:
# Implement a small, self-contained example demonstrating the core concept of Vectors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Vectors in python

# %% [markdown]
# **✨ Task:** Practice Exercise for **Vectors in python**:
# Implement a small, self-contained example demonstrating the core concept of Vectors in python. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Plotting vectors

# %% [markdown]
# **✨ Task:** Practice Exercise for **Plotting vectors**:
# Implement a small, self-contained example demonstrating the core concept of Plotting vectors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 2D vectors

# %% [markdown]
# **✨ Task:** Practice Exercise for **2D vectors**:
# Implement a small, self-contained example demonstrating the core concept of 2D vectors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3D vectors

# %% [markdown]
# **✨ Task:** Practice Exercise for **3D vectors**:
# Implement a small, self-contained example demonstrating the core concept of 3D vectors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Norm

# %% [markdown]
# **✨ Task:** Practice Exercise for **Norm**:
# Implement a small, self-contained example demonstrating the core concept of Norm. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Addition

# %% [markdown]
# **✨ Task:** Practice Exercise for **Addition**:
# Implement a small, self-contained example demonstrating the core concept of Addition. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Multiplication by a scalar

# %% [markdown]
# **✨ Task:** Practice Exercise for **Multiplication by a scalar**:
# Implement a small, self-contained example demonstrating the core concept of Multiplication by a scalar. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Zero, unit and normalized vectors

# %% [markdown]
# **✨ Task:** Practice Exercise for **Zero, unit and normalized vectors**:
# Implement a small, self-contained example demonstrating the core concept of Zero, unit and normalized vectors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Dot product

# %% [markdown]
# **✨ Task:** Practice Exercise for **Dot product**:
# Implement a small, self-contained example demonstrating the core concept of Dot product. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Main properties

# %% [markdown]
# **✨ Task:** Practice Exercise for **Main properties**:
# Implement a small, self-contained example demonstrating the core concept of Main properties. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Calculating the angle between vectors

# %% [markdown]
# **✨ Task:** Practice Exercise for **Calculating the angle between vectors**:
# Implement a small, self-contained example demonstrating the core concept of Calculating the angle between vectors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Projecting a point onto an axis

# %% [markdown]
# **✨ Task:** Practice Exercise for **Projecting a point onto an axis**:
# Implement a small, self-contained example demonstrating the core concept of Projecting a point onto an axis. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Matrices

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrices**:
# Implement a small, self-contained example demonstrating the core concept of Matrices. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Matrices in python

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrices in python**:
# Implement a small, self-contained example demonstrating the core concept of Matrices in python. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Size

# %% [markdown]
# **✨ Task:** Practice Exercise for **Size**:
# Implement a small, self-contained example demonstrating the core concept of Size. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Element indexing

# %% [markdown]
# **✨ Task:** Practice Exercise for **Element indexing**:
# Implement a small, self-contained example demonstrating the core concept of Element indexing. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Square, triangular, diagonal and identity matrices

# %% [markdown]
# **✨ Task:** Practice Exercise for **Square, triangular, diagonal and identity matrices**:
# Implement a small, self-contained example demonstrating the core concept of Square, triangular, diagonal and identity matrices. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Adding matrices

# %% [markdown]
# **✨ Task:** Practice Exercise for **Adding matrices**:
# Implement a small, self-contained example demonstrating the core concept of Adding matrices. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Scalar multiplication

# %% [markdown]
# **✨ Task:** Practice Exercise for **Scalar multiplication**:
# Implement a small, self-contained example demonstrating the core concept of Scalar multiplication. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Matrix multiplication

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrix multiplication**:
# Implement a small, self-contained example demonstrating the core concept of Matrix multiplication. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Matrix transpose

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrix transpose**:
# Implement a small, self-contained example demonstrating the core concept of Matrix transpose. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Converting 1D arrays to 2D arrays in NumPy

# %% [markdown]
# **✨ Task:** Practice Exercise for **Converting 1D arrays to 2D arrays in NumPy**:
# Implement a small, self-contained example demonstrating the core concept of Converting 1D arrays to 2D arrays in NumPy. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Plotting a matrix

# %% [markdown]
# **✨ Task:** Practice Exercise for **Plotting a matrix**:
# Implement a small, self-contained example demonstrating the core concept of Plotting a matrix. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Geometric applications of matrix operations

# %% [markdown]
# **✨ Task:** Practice Exercise for **Geometric applications of matrix operations**:
# Implement a small, self-contained example demonstrating the core concept of Geometric applications of matrix operations. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Addition = multiple geometric translations

# %% [markdown]
# **✨ Task:** Practice Exercise for **Addition = multiple geometric translations**:
# Implement a small, self-contained example demonstrating the core concept of Addition = multiple geometric translations. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Scalar multiplication

# %% [markdown]
# **✨ Task:** Practice Exercise for **Scalar multiplication**:
# Implement a small, self-contained example demonstrating the core concept of Scalar multiplication. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Matrix multiplication – Projection onto an axis

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrix multiplication – Projection onto an axis**:
# Implement a small, self-contained example demonstrating the core concept of Matrix multiplication – Projection onto an axis. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Matrix multiplication – Rotation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrix multiplication – Rotation**:
# Implement a small, self-contained example demonstrating the core concept of Matrix multiplication – Rotation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Matrix multiplication – Other linear transformations

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrix multiplication – Other linear transformations**:
# Implement a small, self-contained example demonstrating the core concept of Matrix multiplication – Other linear transformations. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Matrix inverse

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrix inverse**:
# Implement a small, self-contained example demonstrating the core concept of Matrix inverse. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Determinant

# %% [markdown]
# **✨ Task:** Practice Exercise for **Determinant**:
# Implement a small, self-contained example demonstrating the core concept of Determinant. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Composing linear transformations

# %% [markdown]
# **✨ Task:** Practice Exercise for **Composing linear transformations**:
# Implement a small, self-contained example demonstrating the core concept of Composing linear transformations. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Singular Value Decomposition

# %% [markdown]
# **✨ Task:** Practice Exercise for **Singular Value Decomposition**:
# Implement a small, self-contained example demonstrating the core concept of Singular Value Decomposition. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Eigenvectors and eigenvalues

# %% [markdown]
# **✨ Task:** Practice Exercise for **Eigenvectors and eigenvalues**:
# Implement a small, self-contained example demonstrating the core concept of Eigenvectors and eigenvalues. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Trace

# %% [markdown]
# **✨ Task:** Practice Exercise for **Trace**:
# Implement a small, self-contained example demonstrating the core concept of Trace. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # What's next?

# %% [markdown]
# **✨ Task:** Practice Exercise for **What's next?**:
# Implement a small, self-contained example demonstrating the core concept of What's next?. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
