# %% [markdown]
# # 🏋️ Custom Practice: 05 Math Differential Calculus
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Slope of a straight line

# %% [markdown]
# **✨ Task:** Practice Exercise for **Slope of a straight line**:
# Implement a small, self-contained example demonstrating the core concept of Slope of a straight line. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Defining the slope of a curve

# %% [markdown]
# **✨ Task:** Practice Exercise for **Defining the slope of a curve**:
# Implement a small, self-contained example demonstrating the core concept of Defining the slope of a curve. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Differentiability

# %% [markdown]
# **✨ Task:** Practice Exercise for **Differentiability**:
# Implement a small, self-contained example demonstrating the core concept of Differentiability. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Differentiating a function

# %% [markdown]
# **✨ Task:** Practice Exercise for **Differentiating a function**:
# Implement a small, self-contained example demonstrating the core concept of Differentiating a function. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Example: finding the derivative of $x^2$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Example: finding the derivative of $x^2$**:
# Implement a small, self-contained example demonstrating the core concept of Example: finding the derivative of $x^2$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Notations

# %% [markdown]
# **✨ Task:** Practice Exercise for **Notations**:
# Implement a small, self-contained example demonstrating the core concept of Notations. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Plotting the tangent to a curve

# %% [markdown]
# **✨ Task:** Practice Exercise for **Plotting the tangent to a curve**:
# Implement a small, self-contained example demonstrating the core concept of Plotting the tangent to a curve. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Differentiation rules

# %% [markdown]
# **✨ Task:** Practice Exercise for **Differentiation rules**:
# Implement a small, self-contained example demonstrating the core concept of Differentiation rules. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## The chain rule

# %% [markdown]
# **✨ Task:** Practice Exercise for **The chain rule**:
# Implement a small, self-contained example demonstrating the core concept of The chain rule. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Derivatives and optimization

# %% [markdown]
# **✨ Task:** Practice Exercise for **Derivatives and optimization**:
# Implement a small, self-contained example demonstrating the core concept of Derivatives and optimization. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Higher order derivatives

# %% [markdown]
# **✨ Task:** Practice Exercise for **Higher order derivatives**:
# Implement a small, self-contained example demonstrating the core concept of Higher order derivatives. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Partial derivatives

# %% [markdown]
# **✨ Task:** Practice Exercise for **Partial derivatives**:
# Implement a small, self-contained example demonstrating the core concept of Partial derivatives. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Gradients

# %% [markdown]
# **✨ Task:** Practice Exercise for **Gradients**:
# Implement a small, self-contained example demonstrating the core concept of Gradients. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Gradient Descent, revisited

# %% [markdown]
# **✨ Task:** Practice Exercise for **Gradient Descent, revisited**:
# Implement a small, self-contained example demonstrating the core concept of Gradient Descent, revisited. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Jacobians

# %% [markdown]
# **✨ Task:** Practice Exercise for **Jacobians**:
# Implement a small, self-contained example demonstrating the core concept of Jacobians. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Hessians

# %% [markdown]
# **✨ Task:** Practice Exercise for **Hessians**:
# Implement a small, self-contained example demonstrating the core concept of Hessians. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## A few proofs

# %% [markdown]
# **✨ Task:** Practice Exercise for **A few proofs**:
# Implement a small, self-contained example demonstrating the core concept of A few proofs. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Constant: $f(x)=c$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Constant: $f(x)=c$**:
# Implement a small, self-contained example demonstrating the core concept of Constant: $f(x)=c$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Product rule: $f(x)=g(x)h(x)$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Product rule: $f(x)=g(x)h(x)$**:
# Implement a small, self-contained example demonstrating the core concept of Product rule: $f(x)=g(x)h(x)$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Chain rule: $f(x)=g(h(x))$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Chain rule: $f(x)=g(h(x))$**:
# Implement a small, self-contained example demonstrating the core concept of Chain rule: $f(x)=g(h(x))$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Exponential: $f(x)=\exp(x)=e^x$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Exponential: $f(x)=\exp(x)=e^x$**:
# Implement a small, self-contained example demonstrating the core concept of Exponential: $f(x)=\exp(x)=e^x$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Logarithm: $f(x) = \ln(x)$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Logarithm: $f(x) = \ln(x)$**:
# Implement a small, self-contained example demonstrating the core concept of Logarithm: $f(x) = \ln(x)$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Power rule: $f(x)=x^r$, with $r \neq 0$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Power rule: $f(x)=x^r$, with $r \neq 0$**:
# Implement a small, self-contained example demonstrating the core concept of Power rule: $f(x)=x^r$, with $r \neq 0$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Multiplicative inverse: $f(x)=\dfrac{1}{h(x)}$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Multiplicative inverse: $f(x)=\dfrac{1}{h(x)}$**:
# Implement a small, self-contained example demonstrating the core concept of Multiplicative inverse: $f(x)=\dfrac{1}{h(x)}$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Quotient rule: $f(x)=\dfrac{g(x)}{h(x)}$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Quotient rule: $f(x)=\dfrac{g(x)}{h(x)}$**:
# Implement a small, self-contained example demonstrating the core concept of Quotient rule: $f(x)=\dfrac{g(x)}{h(x)}$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Sin: $f(x)=\sin(x)$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Sin: $f(x)=\sin(x)$**:
# Implement a small, self-contained example demonstrating the core concept of Sin: $f(x)=\sin(x)$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Cosine: $f(x)=\cos(x)$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Cosine: $f(x)=\cos(x)$**:
# Implement a small, self-contained example demonstrating the core concept of Cosine: $f(x)=\cos(x)$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Tangent: $f(x) = \tan(x)$

# %% [markdown]
# **✨ Task:** Practice Exercise for **Tangent: $f(x) = \tan(x)$**:
# Implement a small, self-contained example demonstrating the core concept of Tangent: $f(x) = \tan(x)$. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
