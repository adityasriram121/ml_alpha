# %% [markdown]
# # 🏋️ Custom Practice: 02 Tools Pandas
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Setup

# %% [markdown]
# **✨ Task:** Practice Exercise for **Setup**:
# Implement a small, self-contained example demonstrating the core concept of Setup. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # `Series` objects

# %% [markdown]
# **✨ Task:** Practice Exercise for **`Series` objects**:
# Implement a small, self-contained example demonstrating the core concept of `Series` objects. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Creating a `Series`

# %% [markdown]
# **✨ Task:** Practice Exercise for **Creating a `Series`**:
# Implement a small, self-contained example demonstrating the core concept of Creating a `Series`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Similar to a 1D `ndarray`

# %% [markdown]
# **✨ Task:** Practice Exercise for **Similar to a 1D `ndarray`**:
# Implement a small, self-contained example demonstrating the core concept of Similar to a 1D `ndarray`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Index labels

# %% [markdown]
# **✨ Task:** Practice Exercise for **Index labels**:
# Implement a small, self-contained example demonstrating the core concept of Index labels. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Init from `dict`

# %% [markdown]
# **✨ Task:** Practice Exercise for **Init from `dict`**:
# Implement a small, self-contained example demonstrating the core concept of Init from `dict`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Automatic alignment

# %% [markdown]
# **✨ Task:** Practice Exercise for **Automatic alignment**:
# Implement a small, self-contained example demonstrating the core concept of Automatic alignment. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Init with a scalar

# %% [markdown]
# **✨ Task:** Practice Exercise for **Init with a scalar**:
# Implement a small, self-contained example demonstrating the core concept of Init with a scalar. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## `Series` name

# %% [markdown]
# **✨ Task:** Practice Exercise for **`Series` name**:
# Implement a small, self-contained example demonstrating the core concept of `Series` name. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Plotting a `Series`

# %% [markdown]
# **✨ Task:** Practice Exercise for **Plotting a `Series`**:
# Implement a small, self-contained example demonstrating the core concept of Plotting a `Series`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Handling time

# %% [markdown]
# **✨ Task:** Practice Exercise for **Handling time**:
# Implement a small, self-contained example demonstrating the core concept of Handling time. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Resampling

# %% [markdown]
# **✨ Task:** Practice Exercise for **Resampling**:
# Implement a small, self-contained example demonstrating the core concept of Resampling. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Upsampling and interpolation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Upsampling and interpolation**:
# Implement a small, self-contained example demonstrating the core concept of Upsampling and interpolation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Timezones

# %% [markdown]
# **✨ Task:** Practice Exercise for **Timezones**:
# Implement a small, self-contained example demonstrating the core concept of Timezones. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Periods

# %% [markdown]
# **✨ Task:** Practice Exercise for **Periods**:
# Implement a small, self-contained example demonstrating the core concept of Periods. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # `DataFrame` objects

# %% [markdown]
# **✨ Task:** Practice Exercise for **`DataFrame` objects**:
# Implement a small, self-contained example demonstrating the core concept of `DataFrame` objects. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Multi-indexing

# %% [markdown]
# **✨ Task:** Practice Exercise for **Multi-indexing**:
# Implement a small, self-contained example demonstrating the core concept of Multi-indexing. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Dropping a level

# %% [markdown]
# **✨ Task:** Practice Exercise for **Dropping a level**:
# Implement a small, self-contained example demonstrating the core concept of Dropping a level. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Transposing

# %% [markdown]
# **✨ Task:** Practice Exercise for **Transposing**:
# Implement a small, self-contained example demonstrating the core concept of Transposing. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Stacking and unstacking levels

# %% [markdown]
# **✨ Task:** Practice Exercise for **Stacking and unstacking levels**:
# Implement a small, self-contained example demonstrating the core concept of Stacking and unstacking levels. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Most methods return modified copies

# %% [markdown]
# **✨ Task:** Practice Exercise for **Most methods return modified copies**:
# Implement a small, self-contained example demonstrating the core concept of Most methods return modified copies. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Accessing rows

# %% [markdown]
# **✨ Task:** Practice Exercise for **Accessing rows**:
# Implement a small, self-contained example demonstrating the core concept of Accessing rows. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Adding and removing columns

# %% [markdown]
# **✨ Task:** Add a new column 'Passed' which is True if the Grade is > 70. Then drop the 'Age' column.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Assigning new columns

# %% [markdown]
# **✨ Task:** Practice Exercise for **Assigning new columns**:
# Implement a small, self-contained example demonstrating the core concept of Assigning new columns. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Evaluating an expression

# %% [markdown]
# **✨ Task:** Practice Exercise for **Evaluating an expression**:
# Implement a small, self-contained example demonstrating the core concept of Evaluating an expression. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Querying a `DataFrame`

# %% [markdown]
# **✨ Task:** Practice Exercise for **Querying a `DataFrame`**:
# Implement a small, self-contained example demonstrating the core concept of Querying a `DataFrame`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Sorting a `DataFrame`

# %% [markdown]
# **✨ Task:** Practice Exercise for **Sorting a `DataFrame`**:
# Implement a small, self-contained example demonstrating the core concept of Sorting a `DataFrame`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Plotting a `DataFrame`

# %% [markdown]
# **✨ Task:** Practice Exercise for **Plotting a `DataFrame`**:
# Implement a small, self-contained example demonstrating the core concept of Plotting a `DataFrame`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Operations on `DataFrame`s

# %% [markdown]
# **✨ Task:** Practice Exercise for **Operations on `DataFrame`s**:
# Implement a small, self-contained example demonstrating the core concept of Operations on `DataFrame`s. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Automatic alignment

# %% [markdown]
# **✨ Task:** Practice Exercise for **Automatic alignment**:
# Implement a small, self-contained example demonstrating the core concept of Automatic alignment. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Aggregating with `groupby`

# %% [markdown]
# **✨ Task:** Practice Exercise for **Aggregating with `groupby`**:
# Implement a small, self-contained example demonstrating the core concept of Aggregating with `groupby`. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Pivot tables

# %% [markdown]
# **✨ Task:** Practice Exercise for **Pivot tables**:
# Implement a small, self-contained example demonstrating the core concept of Pivot tables. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Overview functions

# %% [markdown]
# **✨ Task:** Practice Exercise for **Overview functions**:
# Implement a small, self-contained example demonstrating the core concept of Overview functions. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Saving & loading

# %% [markdown]
# **✨ Task:** Practice Exercise for **Saving & loading**:
# Implement a small, self-contained example demonstrating the core concept of Saving & loading. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Saving

# %% [markdown]
# **✨ Task:** Practice Exercise for **Saving**:
# Implement a small, self-contained example demonstrating the core concept of Saving. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Loading

# %% [markdown]
# **✨ Task:** Practice Exercise for **Loading**:
# Implement a small, self-contained example demonstrating the core concept of Loading. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Combining `DataFrame`s

# %% [markdown]
# **✨ Task:** Practice Exercise for **Combining `DataFrame`s**:
# Implement a small, self-contained example demonstrating the core concept of Combining `DataFrame`s. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Concatenation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Concatenation**:
# Implement a small, self-contained example demonstrating the core concept of Concatenation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Categories

# %% [markdown]
# **✨ Task:** Practice Exercise for **Categories**:
# Implement a small, self-contained example demonstrating the core concept of Categories. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # What's next?

# %% [markdown]
# **✨ Task:** Practice Exercise for **What's next?**:
# Implement a small, self-contained example demonstrating the core concept of What's next?. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
