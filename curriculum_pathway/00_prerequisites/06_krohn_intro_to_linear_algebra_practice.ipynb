# %% [markdown]
# # 🏋️ Custom Practice: 06 Krohn Intro To Linear Algebra
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Intro to Linear Algebra

# %% [markdown]
# **✨ Task:** Practice Exercise for **Intro to Linear Algebra**:
# Implement a small, self-contained example demonstrating the core concept of Intro to Linear Algebra. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 1: Data Structures for Algebra

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 1: Data Structures for Algebra**:
# Implement a small, self-contained example demonstrating the core concept of Segment 1: Data Structures for Algebra. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### What Linear Algebra Is

# %% [markdown]
# **✨ Task:** Practice Exercise for **What Linear Algebra Is**:
# Implement a small, self-contained example demonstrating the core concept of What Linear Algebra Is. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Scalars (Rank 0 Tensors) in Base Python

# %% [markdown]
# **✨ Task:** Practice Exercise for **Scalars (Rank 0 Tensors) in Base Python**:
# Implement a small, self-contained example demonstrating the core concept of Scalars (Rank 0 Tensors) in Base Python. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Scalars in PyTorch

# %% [markdown]
# **✨ Task:** Practice Exercise for **Scalars in PyTorch**:
# Implement a small, self-contained example demonstrating the core concept of Scalars in PyTorch. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Scalars in TensorFlow (version 2.0 or later)

# %% [markdown]
# **✨ Task:** Practice Exercise for **Scalars in TensorFlow (version 2.0 or later)**:
# Implement a small, self-contained example demonstrating the core concept of Scalars in TensorFlow (version 2.0 or later). Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Vectors (Rank 1 Tensors) in NumPy

# %% [markdown]
# **✨ Task:** Practice Exercise for **Vectors (Rank 1 Tensors) in NumPy**:
# Implement a small, self-contained example demonstrating the core concept of Vectors (Rank 1 Tensors) in NumPy. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Vector Transposition

# %% [markdown]
# **✨ Task:** Practice Exercise for **Vector Transposition**:
# Implement a small, self-contained example demonstrating the core concept of Vector Transposition. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Zero Vectors

# %% [markdown]
# **✨ Task:** Practice Exercise for **Zero Vectors**:
# Implement a small, self-contained example demonstrating the core concept of Zero Vectors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Vectors in PyTorch and TensorFlow

# %% [markdown]
# **✨ Task:** Practice Exercise for **Vectors in PyTorch and TensorFlow**:
# Implement a small, self-contained example demonstrating the core concept of Vectors in PyTorch and TensorFlow. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### $L^2$ Norm

# %% [markdown]
# **✨ Task:** Practice Exercise for **$L^2$ Norm**:
# Implement a small, self-contained example demonstrating the core concept of $L^2$ Norm. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### $L^1$ Norm

# %% [markdown]
# **✨ Task:** Practice Exercise for **$L^1$ Norm**:
# Implement a small, self-contained example demonstrating the core concept of $L^1$ Norm. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Squared $L^2$ Norm

# %% [markdown]
# **✨ Task:** Practice Exercise for **Squared $L^2$ Norm**:
# Implement a small, self-contained example demonstrating the core concept of Squared $L^2$ Norm. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Max Norm

# %% [markdown]
# **✨ Task:** Practice Exercise for **Max Norm**:
# Implement a small, self-contained example demonstrating the core concept of Max Norm. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Orthogonal Vectors

# %% [markdown]
# **✨ Task:** Practice Exercise for **Orthogonal Vectors**:
# Implement a small, self-contained example demonstrating the core concept of Orthogonal Vectors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Matrices (Rank 2 Tensors) in NumPy

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrices (Rank 2 Tensors) in NumPy**:
# Implement a small, self-contained example demonstrating the core concept of Matrices (Rank 2 Tensors) in NumPy. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Matrices in PyTorch

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrices in PyTorch**:
# Implement a small, self-contained example demonstrating the core concept of Matrices in PyTorch. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Matrices in TensorFlow

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrices in TensorFlow**:
# Implement a small, self-contained example demonstrating the core concept of Matrices in TensorFlow. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Higher-Rank Tensors

# %% [markdown]
# **✨ Task:** Practice Exercise for **Higher-Rank Tensors**:
# Implement a small, self-contained example demonstrating the core concept of Higher-Rank Tensors. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 2: Common Tensor Operations

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 2: Common Tensor Operations**:
# Implement a small, self-contained example demonstrating the core concept of Segment 2: Common Tensor Operations. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Tensor Transposition

# %% [markdown]
# **✨ Task:** Practice Exercise for **Tensor Transposition**:
# Implement a small, self-contained example demonstrating the core concept of Tensor Transposition. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Basic Arithmetical Properties

# %% [markdown]
# **✨ Task:** Practice Exercise for **Basic Arithmetical Properties**:
# Implement a small, self-contained example demonstrating the core concept of Basic Arithmetical Properties. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Reduction

# %% [markdown]
# **✨ Task:** Practice Exercise for **Reduction**:
# Implement a small, self-contained example demonstrating the core concept of Reduction. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### The Dot Product

# %% [markdown]
# **✨ Task:** Practice Exercise for **The Dot Product**:
# Implement a small, self-contained example demonstrating the core concept of The Dot Product. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Solving Linear Systems

# %% [markdown]
# **✨ Task:** Practice Exercise for **Solving Linear Systems**:
# Implement a small, self-contained example demonstrating the core concept of Solving Linear Systems. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 3: Matrix Properties

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 3: Matrix Properties**:
# Implement a small, self-contained example demonstrating the core concept of Segment 3: Matrix Properties. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Frobenius Norm

# %% [markdown]
# **✨ Task:** Practice Exercise for **Frobenius Norm**:
# Implement a small, self-contained example demonstrating the core concept of Frobenius Norm. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Matrix Multiplication (with a Vector)

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrix Multiplication (with a Vector)**:
# Implement a small, self-contained example demonstrating the core concept of Matrix Multiplication (with a Vector). Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Matrix Multiplication (with Two Matrices)

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrix Multiplication (with Two Matrices)**:
# Implement a small, self-contained example demonstrating the core concept of Matrix Multiplication (with Two Matrices). Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Symmetric Matrices

# %% [markdown]
# **✨ Task:** Practice Exercise for **Symmetric Matrices**:
# Implement a small, self-contained example demonstrating the core concept of Symmetric Matrices. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Identity Matrices

# %% [markdown]
# **✨ Task:** Practice Exercise for **Identity Matrices**:
# Implement a small, self-contained example demonstrating the core concept of Identity Matrices. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Answers to Matrix Multiplication Qs

# %% [markdown]
# **✨ Task:** Practice Exercise for **Answers to Matrix Multiplication Qs**:
# Implement a small, self-contained example demonstrating the core concept of Answers to Matrix Multiplication Qs. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Matrix Inversion

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrix Inversion**:
# Implement a small, self-contained example demonstrating the core concept of Matrix Inversion. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Matrix Inversion Where No Solution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Matrix Inversion Where No Solution**:
# Implement a small, self-contained example demonstrating the core concept of Matrix Inversion Where No Solution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Orthogonal Matrices

# %% [markdown]
# **✨ Task:** Practice Exercise for **Orthogonal Matrices**:
# Implement a small, self-contained example demonstrating the core concept of Orthogonal Matrices. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
