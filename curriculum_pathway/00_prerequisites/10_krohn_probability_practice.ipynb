# %% [markdown]
# # 🏋️ Custom Practice: 10 Krohn Probability
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Probability & Information Theory

# %% [markdown]
# **✨ Task:** Practice Exercise for **Probability & Information Theory**:
# Implement a small, self-contained example demonstrating the core concept of Probability & Information Theory. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 1: Introduction to Probability

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 1: Introduction to Probability**:
# Implement a small, self-contained example demonstrating the core concept of Segment 1: Introduction to Probability. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### What Probability Theory Is

# %% [markdown]
# **✨ Task:** Practice Exercise for **What Probability Theory Is**:
# Implement a small, self-contained example demonstrating the core concept of What Probability Theory Is. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Events and Sample Spaces

# %% [markdown]
# **✨ Task:** Practice Exercise for **Events and Sample Spaces**:
# Implement a small, self-contained example demonstrating the core concept of Events and Sample Spaces. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Multiple Independent Observations

# %% [markdown]
# **✨ Task:** Practice Exercise for **Multiple Independent Observations**:
# Implement a small, self-contained example demonstrating the core concept of Multiple Independent Observations. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Combining Probabilities

# %% [markdown]
# **✨ Task:** Practice Exercise for **Combining Probabilities**:
# Implement a small, self-contained example demonstrating the core concept of Combining Probabilities. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Combinatorics

# %% [markdown]
# **✨ Task:** Practice Exercise for **Combinatorics**:
# Implement a small, self-contained example demonstrating the core concept of Combinatorics. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### The Law of Large Numbers

# %% [markdown]
# **✨ Task:** Practice Exercise for **The Law of Large Numbers**:
# Implement a small, self-contained example demonstrating the core concept of The Law of Large Numbers. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Statistics

# %% [markdown]
# **✨ Task:** Practice Exercise for **Statistics**:
# Implement a small, self-contained example demonstrating the core concept of Statistics. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Expected Value

# %% [markdown]
# **✨ Task:** Practice Exercise for **Expected Value**:
# Implement a small, self-contained example demonstrating the core concept of Expected Value. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Measures of Central Tendency

# %% [markdown]
# **✨ Task:** Practice Exercise for **Measures of Central Tendency**:
# Implement a small, self-contained example demonstrating the core concept of Measures of Central Tendency. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Mean

# %% [markdown]
# **✨ Task:** Practice Exercise for **Mean**:
# Implement a small, self-contained example demonstrating the core concept of Mean. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Median

# %% [markdown]
# **✨ Task:** Practice Exercise for **Median**:
# Implement a small, self-contained example demonstrating the core concept of Median. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Mode

# %% [markdown]
# **✨ Task:** Practice Exercise for **Mode**:
# Implement a small, self-contained example demonstrating the core concept of Mode. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Quantiles

# %% [markdown]
# **✨ Task:** Practice Exercise for **Quantiles**:
# Implement a small, self-contained example demonstrating the core concept of Quantiles. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### The Box-and-Whisker Plot

# %% [markdown]
# **✨ Task:** Practice Exercise for **The Box-and-Whisker Plot**:
# Implement a small, self-contained example demonstrating the core concept of The Box-and-Whisker Plot. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Measures of Dispersion

# %% [markdown]
# **✨ Task:** Practice Exercise for **Measures of Dispersion**:
# Implement a small, self-contained example demonstrating the core concept of Measures of Dispersion. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Standard Deviation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Standard Deviation**:
# Implement a small, self-contained example demonstrating the core concept of Standard Deviation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Standard Error

# %% [markdown]
# **✨ Task:** Practice Exercise for **Standard Error**:
# Implement a small, self-contained example demonstrating the core concept of Standard Error. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Measures of Relatedness

# %% [markdown]
# **✨ Task:** Practice Exercise for **Measures of Relatedness**:
# Implement a small, self-contained example demonstrating the core concept of Measures of Relatedness. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Correlation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Correlation**:
# Implement a small, self-contained example demonstrating the core concept of Correlation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 2: Distributions in Machine Learning

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 2: Distributions in Machine Learning**:
# Implement a small, self-contained example demonstrating the core concept of Segment 2: Distributions in Machine Learning. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Uniform

# %% [markdown]
# **✨ Task:** Practice Exercise for **Uniform**:
# Implement a small, self-contained example demonstrating the core concept of Uniform. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Gaussian

# %% [markdown]
# **✨ Task:** Practice Exercise for **Gaussian**:
# Implement a small, self-contained example demonstrating the core concept of Gaussian. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### The Central Limit Theorem

# %% [markdown]
# **✨ Task:** Practice Exercise for **The Central Limit Theorem**:
# Implement a small, self-contained example demonstrating the core concept of The Central Limit Theorem. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Sampling from a skewed distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Sampling from a skewed distribution**:
# Implement a small, self-contained example demonstrating the core concept of Sampling from a skewed distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Sampling from a multimodal distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Sampling from a multimodal distribution**:
# Implement a small, self-contained example demonstrating the core concept of Sampling from a multimodal distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Sampling from uniform

# %% [markdown]
# **✨ Task:** Practice Exercise for **Sampling from uniform**:
# Implement a small, self-contained example demonstrating the core concept of Sampling from uniform. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Log-Normal Distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Log-Normal Distribution**:
# Implement a small, self-contained example demonstrating the core concept of Log-Normal Distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Exponential Distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Exponential Distribution**:
# Implement a small, self-contained example demonstrating the core concept of Exponential Distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Laplace Distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Laplace Distribution**:
# Implement a small, self-contained example demonstrating the core concept of Laplace Distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Binomial Distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Binomial Distribution**:
# Implement a small, self-contained example demonstrating the core concept of Binomial Distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Fair coin (p = 0.5)

# %% [markdown]
# **✨ Task:** Practice Exercise for **Fair coin (p = 0.5)**:
# Implement a small, self-contained example demonstrating the core concept of Fair coin (p = 0.5). Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Weighted coin (p = 0.8)

# %% [markdown]
# **✨ Task:** Practice Exercise for **Weighted coin (p = 0.8)**:
# Implement a small, self-contained example demonstrating the core concept of Weighted coin (p = 0.8). Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Multinomial Distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Multinomial Distribution**:
# Implement a small, self-contained example demonstrating the core concept of Multinomial Distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Poisson Distribution

# %% [markdown]
# **✨ Task:** Practice Exercise for **Poisson Distribution**:
# Implement a small, self-contained example demonstrating the core concept of Poisson Distribution. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Mixture Distributions

# %% [markdown]
# **✨ Task:** Practice Exercise for **Mixture Distributions**:
# Implement a small, self-contained example demonstrating the core concept of Mixture Distributions. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 3: Information Theory

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 3: Information Theory**:
# Implement a small, self-contained example demonstrating the core concept of Segment 3: Information Theory. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Shannon and Differential Entropy

# %% [markdown]
# **✨ Task:** Practice Exercise for **Shannon and Differential Entropy**:
# Implement a small, self-contained example demonstrating the core concept of Shannon and Differential Entropy. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Kullback-Leibler Divergence

# %% [markdown]
# **✨ Task:** Practice Exercise for **Kullback-Leibler Divergence**:
# Implement a small, self-contained example demonstrating the core concept of Kullback-Leibler Divergence. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Cross-Entropy

# %% [markdown]
# **✨ Task:** Practice Exercise for **Cross-Entropy**:
# Implement a small, self-contained example demonstrating the core concept of Cross-Entropy. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
