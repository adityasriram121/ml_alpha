# %% [markdown]
# # 🏋️ Custom Practice: 08 Krohn Calculus I
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Calculus I: Limits & Derivatives

# %% [markdown]
# **✨ Task:** Practice Exercise for **Calculus I: Limits & Derivatives**:
# Implement a small, self-contained example demonstrating the core concept of Calculus I: Limits & Derivatives. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 1: Limits

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 1: Limits**:
# Implement a small, self-contained example demonstrating the core concept of Segment 1: Limits. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### The Calculus of Infinitesimals

# %% [markdown]
# **✨ Task:** Practice Exercise for **The Calculus of Infinitesimals**:
# Implement a small, self-contained example demonstrating the core concept of The Calculus of Infinitesimals. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Limits

# %% [markdown]
# **✨ Task:** Practice Exercise for **Limits**:
# Implement a small, self-contained example demonstrating the core concept of Limits. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 2: Computing Derivatives with Differentiation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 2: Computing Derivatives with Differentiation**:
# Implement a small, self-contained example demonstrating the core concept of Segment 2: Computing Derivatives with Differentiation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Segment 3: Automatic Differentiation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Segment 3: Automatic Differentiation**:
# Implement a small, self-contained example demonstrating the core concept of Segment 3: Automatic Differentiation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Autodiff with PyTorch

# %% [markdown]
# **✨ Task:** Practice Exercise for **Autodiff with PyTorch**:
# Implement a small, self-contained example demonstrating the core concept of Autodiff with PyTorch. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Autodiff with TensorFlow

# %% [markdown]
# **✨ Task:** Practice Exercise for **Autodiff with TensorFlow**:
# Implement a small, self-contained example demonstrating the core concept of Autodiff with TensorFlow. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
