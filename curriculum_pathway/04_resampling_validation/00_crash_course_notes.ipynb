# %% [markdown]
# # Concept 04: Resampling & Validation (Crash Course Notes)
#
# Validating model capacity to generalize to unseen datasets.
#
# ## 📖 Readings Reference
# * **ISLP**: Chapter 5 (Resampling Methods).
#
# ## 📐 Mathematical Foundations
# 1. **LOOCV (Leave-One-Out CV)**: Iteratively uses 1 sample for validation and $m-1$ samples for training.
# 2. **The Bootstrap**: Randomly sampling with replacement to generate $B$ datasets of size $m$, estimating model variance.
#
# ---
#
# ## 💻 Coding Tasks (Your Turn)

# %%
from sklearn.utils import resample

# Task 1: Bootstrap resampling
# Generate one bootstrap dataset from arrays X and y.
def get_bootstrap_sample(X, y):
    ### YOUR CODE HERE
    X_b, y_b = None, None
    ### END CODE
    return X_b, y_b

# %% [markdown]
# ## ❓ Socratic Checkpoints
# 1. Why is K-Fold Cross-Validation preferred over a single validation set?
# 2. What are the variance and bias trade-offs of LOOCV ($K=m$) vs. 10-Fold CV ($K=10$)?
# 3. Explain how the Bootstrap is used to calculate confidence intervals for model coefficients.
