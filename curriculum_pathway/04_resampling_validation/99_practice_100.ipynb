# %% [markdown]
# # 🏋️ Practice Problems: 04_RESAMPLING_VALIDATION
# ## Cross-Validation & Resampling Techniques
#
# **Topics**: k-fold CV, stratified CV, bootstrap, leave-one-out, time series CV
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What is k-fold cross-validation? Why is it better than a single train/test split?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Reduces variance, uses data efficiently.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain stratified k-fold. When is it critical to use?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Preserves class distribution in imbalanced datasets.</details>

# %% [markdown]
# **Q3.** [⭐] What is bootstrap resampling? How does it estimate uncertainty?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Sample with replacement, compute statistic for each sample.</details>

# %% [markdown]
# **Q4.** [⭐⭐] True or False: Leave-one-out CV is always better than k-fold CV. Justify.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>LOOCV has high variance, slow to compute.</details>

# %% [markdown]
# **Q5.** [⭐⭐⭐] Explain time series cross-validation. Why can't you shuffle time series data?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Temporal dependence = shuffling breaks structure.</details>

# %% [markdown]
# **Q6.** [⭐] What is nested cross-validation? When do you need it?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Outer loop for evaluation, inner loop for hyperparameter selection.</details>

# %% [markdown]
# **Q7.** [⭐⭐] Define recall and precision for imbalanced datasets. Which matters more for fraud detection?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Recall: catch all frauds. Precision: minimize false alarms.</details>

# %% [markdown]
# **Q8.** [⭐⭐] What is a confusion matrix for multiclass classification?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Rows=true, columns=predicted. Diagonal=correct.</details>

# %% [markdown]
# **Q9.** [⭐] Explain the difference between validation set and test set.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Validation: tune hyperparams. Test: final evaluation.</details>

# %% [markdown]
# **Q10.** [⭐⭐⭐] How do you estimate generalization error with cross-validation?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Average test error across folds.</details>

# %% [markdown]
# **Q11-Q35.** Continue with more conceptual problems.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Derive the expected value of a bootstrap sample mean.

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>E[sample mean] = population mean.</details>

# %% [markdown]
# **Q37.** [⭐⭐] Show that k-fold CV error is an unbiased estimator of test error.

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Each fold is independent and representative.</details>

# %% [markdown]
# **Q38-Q65.** Continue with more theoretical problems.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Implement 5-fold CV by hand on Auto data (no sklearn). Report mean and std MSE.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>Use np.array_split() to create folds.</details>

# %% [markdown]
# **Q67.** [⭐⭐] Compare 5-fold, 10-fold, and LOOCV on a model. Which is fastest? Which has lowest variance?

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>LOOCV is slow, high variance. More folds = lower variance.</details>

# %% [markdown]
# **Q68-Q100.** Continue with more practical problems.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
