# %% [markdown]
# # 🏋️ Practice Problems: 09_DIMENSIONALITY_REDUCTION
# ## Dimensionality Reduction & PCA
#
# **Topics**: PCA, variance explained, eigendecomposition, feature selection
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What is PCA? What does it maximize?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Finds directions of max variance.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain the relationship between eigenvalues and variance explained in PCA.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Eigenvalue = variance along eigenvector.</details>

# %% [markdown]
# **Q3-Q35.** Continue with more conceptual problems on PCA, scree plots, curse of dimensionality.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Derive the PCA objective: maximize variance in direction w subject to ||w||=1.

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Maximize w^T Σ w.</details>

# %% [markdown]
# **Q37-Q65.** Continue with theoretical problems on eigenvectors, reconstruction error, explained variance.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Apply PCA to Iris. Visualize 2 components. How much variance is explained?

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>Use PCA(n_components=2).</details>

# %% [markdown]
# **Q67-Q100.** Continue with scree plots, reconstruction, classification with/without PCA.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
