# %% [markdown]
# # Concept 09: Dimensionality Reduction (Crash Course Notes)
#
# Compressing datasets by identifying principal directions of variation.
#
# ## 📖 Readings Reference
# * **HOML3**: Chapter 8 (Dimensionality Reduction).
# * **ISLP**: Chapter 6 (PCR) & Chapter 12 (PCA).
#
# ## 📐 Mathematical Foundations
# 1. **Singular Value Decomposition (SVD)**:
#    $$X = U \Sigma V^T$$
#    where $V$ contains the principal components.
# 2. **Explained Variance**:
#    $$\text{VarRatio}_i = \frac{\sigma_i^2}{\sum \sigma_j^2}$$
#
# ---
#
# ## 💻 Coding Tasks (Your Turn)

# %%
from sklearn.decomposition import PCA

# Task 1: PCA Projection
# Reduce a dataset X of shape (50, 5) to 2 principal components.
X = np.random.randn(50, 5)
### YOUR CODE HERE
pca = None
X_reduced = None
### END CODE
print("Shape of X_reduced:", X_reduced.shape if X_reduced is not None else None)

# %% [markdown]
# ## ❓ Socratic Checkpoints
# 1. What is the Curse of Dimensionality, and how does PCA mitigate it?
# 2. Explain the difference between PCA (unsupervised projection) and Linear Discriminant Analysis (LDA, supervised classification projection).
# 3. How do you select the optimal number of principal components?
