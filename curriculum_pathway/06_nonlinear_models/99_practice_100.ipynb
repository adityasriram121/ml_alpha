# %% [markdown]
# # 🏋️ Practice Problems: 06_NONLINEAR_MODELS
# ## Polynomial & Spline Regression
#
# **Topics**: polynomial features, splines, basis functions, kernel tricks
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What are polynomial features? How do you add them to a dataset?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Add x^2, x^3, interactions like x1*x2.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain the curse of dimensionality. Why does polynomial expansion make it worse?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>More features = more parameters = more overfitting.</details>

# %% [markdown]
# **Q3-Q35.** Continue with more conceptual problems on polynomials, splines, basis functions, kernel tricks.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Show that polynomial regression y = b + w1*x + w2*x^2 + ... is still linear in the parameters.

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>It's linear in w, just nonlinear features.</details>

# %% [markdown]
# **Q37-Q65.** Continue with theoretical problems on basis functions, splines, kernel tricks.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Add polynomial features (degree 1-5) to Auto data. Fit linear regression for each. Plot train/test error.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>Use PolynomialFeatures() from sklearn.</details>

# %% [markdown]
# **Q67-Q100.** Continue with splines, interactions, RBF basis, custom feature engineering.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
