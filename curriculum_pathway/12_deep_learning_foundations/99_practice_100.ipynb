# %% [markdown]
# # 🏋️ Practice Problems: 12_DEEP_LEARNING_FOUNDATIONS
# ## Neural Networks & Backpropagation
#
# **Topics**: MLPs, activation functions, backprop, SGD, PyTorch basics
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What is a neural network? Explain layers, neurons, weights.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Layers of neurons connected by weights.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain activation functions. Why do we need them?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Introduce nonlinearity; otherwise MLP = linear.</details>

# %% [markdown]
# **Q3-Q35.** Continue with more conceptual problems on forward/backward pass, vanishing gradients, ReLU vs sigmoid.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Derive gradient of MSE loss: dL/dŷ = 2(ŷ - y) / n.

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>d/dŷ[(ŷ - y)^2].</details>

# %% [markdown]
# **Q37-Q65.** Continue with theoretical problems on backprop, chain rule, SGD update, ReLU gradients.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Implement a tiny 2-layer MLP in NumPy. Forward pass only.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>y = σ(w2 * σ(w1 * x + b1) + b2).</details>

# %% [markdown]
# **Q67-Q100.** Continue with backprop implementation, SGD training, PyTorch basics.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
