# %% [markdown]
# # Concept 12: Neural Networks & Deep Learning Foundations (Crash Course Notes)
#
# Understanding artificial neural networks, activation functions, and backpropagation gradients.
#
# ## 📖 Readings Reference
# * **ISLP**: Chapter 10 (Deep Learning).
# * **HOML3**: Chapters 10, 11, 12, 13.
#
# ## 📐 Mathematical Foundations
# 1. **Linear Layer**:
#    $$Z = X W + b$$
# 2. **ReLU Activation**:
#    $$\text{ReLU}(z) = \max(0, z)$$
# 3. **Gradient of loss with respect to final logits $Z$**:
#    $$dZ = A - Y$$
#
# ---
#
# ## 💻 Coding Tasks (Your Turn)

# %%
# Task 1: Forward layer activation in numpy
def forward_dense_relu(X, W, b):
    ### YOUR CODE HERE
    Z = None
    A = None
    ### END CODE
    return A, Z

# %% [markdown]
# ## ❓ Socratic Checkpoints
# 1. Why does backpropagation require storing activations during the forward pass?
# 2. Explain the vanishing gradient problem. How do ELU/Swish and Batch Normalization help solve it?
# 3. Why is custom layer subclassing in Keras/TensorFlow necessary for complex research architectures?
