# %% [markdown]
# # 🏋️ Custom Practice: 01 Ch03-Linreg-Lab
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# ## Importing packages

# %% [markdown]
# **✨ Task:** Practice Exercise for **Importing packages**:
# Implement a small, self-contained example demonstrating the core concept of Importing packages. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### New imports

# %% [markdown]
# **✨ Task:** Practice Exercise for **New imports**:
# Implement a small, self-contained example demonstrating the core concept of New imports. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Inspecting Objects and Namespaces

# %% [markdown]
# **✨ Task:** Practice Exercise for **Inspecting Objects and Namespaces**:
# Implement a small, self-contained example demonstrating the core concept of Inspecting Objects and Namespaces. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Simple Linear Regression

# %% [markdown]
# **✨ Task:** Use statsmodels or scikit-learn to fit a simple linear regression predicting 'medv' from 'lstat' in the Boston dataset. Print the coefficients.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Defining Functions

# %% [markdown]
# **✨ Task:** Practice Exercise for **Defining Functions**:
# Implement a small, self-contained example demonstrating the core concept of Defining Functions. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Multiple Linear Regression

# %% [markdown]
# **✨ Task:** Expand your model to use all available predictors. Identify which predictors have p-values > 0.05.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Multivariate Goodness of Fit

# %% [markdown]
# **✨ Task:** Practice Exercise for **Multivariate Goodness of Fit**:
# Implement a small, self-contained example demonstrating the core concept of Multivariate Goodness of Fit. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Non-linear Transformations of the Predictors

# %% [markdown]
# **✨ Task:** Add a polynomial feature (e.g. lstat squared) to the regression to capture non-linear effects.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Qualitative Predictors

# %% [markdown]
# **✨ Task:** Load a dataset with categorical variables. Use pandas `get_dummies()` to one-hot encode them before fitting a regression.

# %%
# YOUR CODE HERE
