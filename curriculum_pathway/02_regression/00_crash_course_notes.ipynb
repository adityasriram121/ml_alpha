# %% [markdown]
# # Concept 02: Regression Models (Crash Course Notes)
#
# Focuses on fitting models to continuous real-valued targets.
#
# ## 📖 Readings Reference
# * **ISLP**: Chapter 3 (Linear Regression).
# * **HOML3**: Chapter 4 (Training Models).
#
# ## 📐 Mathematical Foundations
# 1. **Normal Equation**:
#    $$\theta = (X^T X)^{-1} X^T y$$
# 2. **Gradient Step (Batch Gradient Descent)**:
#    $$\theta^{(next)} = \theta - \frac{\eta}{m} X^T (X\theta - y)$$
#
# ---
#
# ## 💻 Coding Tasks (Your Turn)

# %%
# Task 1: Batch Gradient Descent step
# Write a function that performs ONE gradient descent step update for theta.
def gd_step(X, y, theta, eta):
    m = len(y)
    ### YOUR CODE HERE
    gradients = None
    theta_next = None
    ### END CODE
    return theta_next

# %% [markdown]
# ## ❓ Socratic Checkpoints
# 1. What happens to the matrix $X^T X$ when features are collinear (multi-collinearity)? How does that affect the Normal Equation?
# 2. Compare the computational complexity of the Normal Equation ($O(n^3)$) vs. Gradient Descent ($O(k \cdot m \cdot n)$). When should you choose which?
# 3. Why is scaling features vital before running Gradient Descent?
