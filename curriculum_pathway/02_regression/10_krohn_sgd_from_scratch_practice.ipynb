# %% [markdown]
# # 🏋️ Custom Practice: 10 Krohn Sgd From Scratch
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Stochastic Gradient Descent from Scratch

# %% [markdown]
# **✨ Task:** Practice Exercise for **Stochastic Gradient Descent from Scratch**:
# Implement a small, self-contained example demonstrating the core concept of Stochastic Gradient Descent from Scratch. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Simulate data

# %% [markdown]
# **✨ Task:** Practice Exercise for **Simulate data**:
# Implement a small, self-contained example demonstrating the core concept of Simulate data. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Define model and "randomly" initialize model parameters

# %% [markdown]
# **✨ Task:** Practice Exercise for **Define model and "randomly" initialize model parameters**:
# Implement a small, self-contained example demonstrating the core concept of Define model and "randomly" initialize model parameters. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Optimize parameters via SGD

# %% [markdown]
# **✨ Task:** Practice Exercise for **Optimize parameters via SGD**:
# Implement a small, self-contained example demonstrating the core concept of Optimize parameters via SGD. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Rinse and Repeat

# %% [markdown]
# **✨ Task:** Practice Exercise for **Rinse and Repeat**:
# Implement a small, self-contained example demonstrating the core concept of Rinse and Repeat. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
