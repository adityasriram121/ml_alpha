# %% [markdown]
# # 🏋️ Custom Practice: 08 Krohn Batch Regression Gradient
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Gradient of Cost on a Batch of Data

# %% [markdown]
# **✨ Task:** Practice Exercise for **Gradient of Cost on a Batch of Data**:
# Implement a small, self-contained example demonstrating the core concept of Gradient of Cost on a Batch of Data. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Rinse and Repeat

# %% [markdown]
# **✨ Task:** Practice Exercise for **Rinse and Repeat**:
# Implement a small, self-contained example demonstrating the core concept of Rinse and Repeat. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
