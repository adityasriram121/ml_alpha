# %% [markdown]
# # 🏋️ Custom Practice: 02 Training Linear Models
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Setup

# %% [markdown]
# **✨ Task:** Practice Exercise for **Setup**:
# Implement a small, self-contained example demonstrating the core concept of Setup. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Linear Regression

# %% [markdown]
# **✨ Task:** Implement the Normal Equation mathematically using `np.linalg.inv` to solve for the theta parameters on a synthetic dataset.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## The Normal Equation

# %% [markdown]
# **✨ Task:** Practice Exercise for **The Normal Equation**:
# Implement a small, self-contained example demonstrating the core concept of The Normal Equation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# **✨ Task:** Write a from-scratch Batch Gradient Descent loop. Run it for 1000 iterations and track the MSE loss over time.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Stochastic Gradient Descent

# %% [markdown]
# **✨ Task:** Modify your gradient descent to update weights using only a single random instance at each step (SGD).

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Mini-batch gradient descent

# %% [markdown]
# **✨ Task:** Write a from-scratch Batch Gradient Descent loop. Run it for 1000 iterations and track the MSE loss over time.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# **✨ Task:** Use `PolynomialFeatures(degree=2)` from sklearn to transform a dataset, then fit a Linear Regression model to it.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Learning Curves

# %% [markdown]
# **✨ Task:** Plot the training and validation learning curves for a model to diagnose whether it is underfitting or overfitting.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Regularized Linear Models

# %% [markdown]
# **✨ Task:** Train a Ridge, Lasso, and ElasticNet model. Compare their coefficients to see how Lasso drives some to exactly zero.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# **✨ Task:** Practice Exercise for **Ridge Regression**:
# Implement a small, self-contained example demonstrating the core concept of Ridge Regression. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Lasso Regression

# %% [markdown]
# **✨ Task:** Practice Exercise for **Lasso Regression**:
# Implement a small, self-contained example demonstrating the core concept of Lasso Regression. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Elastic Net

# %% [markdown]
# **✨ Task:** Practice Exercise for **Elastic Net**:
# Implement a small, self-contained example demonstrating the core concept of Elastic Net. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Early Stopping

# %% [markdown]
# **✨ Task:** Practice Exercise for **Early Stopping**:
# Implement a small, self-contained example demonstrating the core concept of Early Stopping. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# **✨ Task:** Practice Exercise for **Logistic Regression**:
# Implement a small, self-contained example demonstrating the core concept of Logistic Regression. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Estimating Probabilities

# %% [markdown]
# **✨ Task:** Practice Exercise for **Estimating Probabilities**:
# Implement a small, self-contained example demonstrating the core concept of Estimating Probabilities. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Decision Boundaries

# %% [markdown]
# **✨ Task:** Practice Exercise for **Decision Boundaries**:
# Implement a small, self-contained example demonstrating the core concept of Decision Boundaries. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Softmax Regression

# %% [markdown]
# **✨ Task:** Practice Exercise for **Softmax Regression**:
# Implement a small, self-contained example demonstrating the core concept of Softmax Regression. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Exercise solutions

# %% [markdown]
# **✨ Task:** Practice Exercise for **Exercise solutions**:
# Implement a small, self-contained example demonstrating the core concept of Exercise solutions. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 1. to 11.

# %% [markdown]
# **✨ Task:** Practice Exercise for **1. to 11.**:
# Implement a small, self-contained example demonstrating the core concept of 1. to 11.. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 12. Batch Gradient Descent with early stopping for Softmax Regression

# %% [markdown]
# **✨ Task:** Write a from-scratch Batch Gradient Descent loop. Run it for 1000 iterations and track the MSE loss over time.

# %%
# YOUR CODE HERE
