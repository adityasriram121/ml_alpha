# %% [markdown]
# # 🏋️ Custom Practice: 03 Extra Gradient Descent Comparison
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Comparison of Batch, Mini-Batch and Stochastic Gradient Descent

# %% [markdown]
# **✨ Task:** Practice Exercise for **Comparison of Batch, Mini-Batch and Stochastic Gradient Descent**:
# Implement a small, self-contained example demonstrating the core concept of Comparison of Batch, Mini-Batch and Stochastic Gradient Descent. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
