# %% [markdown]
# # 🏋️ Custom Practice: 04 Extra Autodiff
# *This notebook mirrors the structure of the lesson. Complete the unique exercises for each section.*

# %% [markdown]
# # Setup

# %% [markdown]
# **✨ Task:** Practice Exercise for **Setup**:
# Implement a small, self-contained example demonstrating the core concept of Setup. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Introduction

# %% [markdown]
# **✨ Task:** Practice Exercise for **Introduction**:
# Implement a small, self-contained example demonstrating the core concept of Introduction. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Numeric differentiation

# %% [markdown]
# **✨ Task:** Practice Exercise for **Numeric differentiation**:
# Implement a small, self-contained example demonstrating the core concept of Numeric differentiation. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Implementing a Toy Computation Graph

# %% [markdown]
# **✨ Task:** Practice Exercise for **Implementing a Toy Computation Graph**:
# Implement a small, self-contained example demonstrating the core concept of Implementing a Toy Computation Graph. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Computing gradients

# %% [markdown]
# **✨ Task:** Practice Exercise for **Computing gradients**:
# Implement a small, self-contained example demonstrating the core concept of Computing gradients. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Forward mode autodiff

# %% [markdown]
# **✨ Task:** Practice Exercise for **Forward mode autodiff**:
# Implement a small, self-contained example demonstrating the core concept of Forward mode autodiff. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Forward mode autodiff using dual numbers

# %% [markdown]
# **✨ Task:** Practice Exercise for **Forward mode autodiff using dual numbers**:
# Implement a small, self-contained example demonstrating the core concept of Forward mode autodiff using dual numbers. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Reverse mode autodiff

# %% [markdown]
# **✨ Task:** Practice Exercise for **Reverse mode autodiff**:
# Implement a small, self-contained example demonstrating the core concept of Reverse mode autodiff. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Reverse mode autodiff using TensorFlow

# %% [markdown]
# **✨ Task:** Practice Exercise for **Reverse mode autodiff using TensorFlow**:
# Implement a small, self-contained example demonstrating the core concept of Reverse mode autodiff using TensorFlow. Do not copy the original notebook code exactly; invent your own dummy data or scenario.

# %%
# YOUR CODE HERE
