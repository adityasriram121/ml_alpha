# %% [markdown]
# # 🏋️ Practice Problems: 02_REGRESSION
# ## Linear Regression & Gradient Descent
#
# **Topics covered**: least squares, normal equations, gradient descent, feature scaling, regularization
#
# This notebook contains 100 practice problems:
# - 🧠 **Conceptual** (Q1-Q35): Explain, compare, true/false with justification
# - 📐 **Theoretical** (Q36-Q65): Derivations, proofs, mathematical formulations
# - 💻 **Practical** (Q66-Q100): Code implementations, data analysis, plotting
#
# **Difficulty levels**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)
#
# **Datasets**: Auto.csv, synthetic

# %% [markdown]
# ## 🧠 Conceptual Problems (Q1 - Q35)

# %% [markdown]
# **Q1.** [⭐] What is linear regression? What does 'fitting' a line mean mathematically?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Minimizing sum of squared errors.
#
# </details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain: simple (1 feature) vs multiple (many features) regression.

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Y = b + m*X vs Y = b + w1*X1 + w2*X2 + ...
#
# </details>

# %% [markdown]
# **Q3.** [⭐⭐] Why use gradient descent instead of normal equations?

# %% [markdown]
# *Your answer here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# GD is iterative, works on huge datasets, easier for some problems.
#
# </details>

# %% [markdown]
# **Q4-Q35.** Fill in with additional conceptual problems.

# %% [markdown]
# ## 📐 Theoretical Problems (Q36 - Q65)

# %% [markdown]
# **Q36.** [⭐] Derive the normal equations for simple linear regression: minimize SSE by setting derivatives to 0.

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# SSE = Σ(y_i - (b + m*x_i))². Find m and b.
#
# </details>

# %% [markdown]
# **Q37.** [⭐⭐] Derive dL/dw for MSE loss where L = (1/n)Σ(y - ŷ)².

# %% [markdown]
# *Your derivation here...*

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Chain rule: dL/dw = (1/n) * 2 * Σ(y - ŷ) * (-x).
#
# </details>

# %% [markdown]
# **Q38-Q65.** Fill in with additional theoretical problems.

# %% [markdown]
# ## 💻 Practical Problems (Q66 - Q100)

# %% [markdown]
# **Q66.** [⭐] Compute linear regression manually: Y = b + m*X using Auto data (MPG from weight). Formula: m = cov(X,Y)/var(X), b = ȳ - m*x̄.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Use np.cov(), np.var().
#
# </details>

# %% [markdown]
# **Q67.** [⭐⭐] Implement gradient descent from scratch for linear regression. Train on Auto (MPG from weight). Plot loss vs iteration. Report final MSE.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>
#
# Init w=(0,0), loop: compute grad, update w.
#
# </details>

# %% [markdown]
# **Q68-Q100.** Fill in with additional practical problems.

# %% [markdown]
# ---
#
# ## 📝 How to use this notebook:
#
# 1. **Work through problems in order** within each section
# 2. **Use hints liberally** — they point you in the right direction
# 3. **Compare with solutions** after completing (once posted)
# 4. **Challenge yourself** — skip to harder problems (⭐⭐⭐) if you're comfortable
# 5. **Revisit regularly** — revisiting problems helps consolidate learning
#
# Good luck! 🚀
