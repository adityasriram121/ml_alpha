# %% [markdown]
# # 🏋️ Practice Problems: 13_ADVANCED_DEEP_LEARNING
# ## CNNs, RNNs, Transformers, & Transfer Learning
#
# **Topics**: convolutions, RNNs/LSTMs, attention, transformers, transfer learning
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What is a convolution in CNNs? Why use it for images?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Local feature detection, weight sharing.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain pooling. What does max-pooling do?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Reduces spatial dimensions, keeps strong features.</details>

# %% [markdown]
# **Q3-Q35.** Continue with RNNs, LSTMs, attention, transformers, transfer learning concepts.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Derive the convolution operation: y[i,j] = Σ_k Σ_l w[k,l] * x[i+k, j+l].

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Sliding window, element-wise multiplication, sum.</details>

# %% [markdown]
# **Q37-Q65.** Continue with RNN recurrence, LSTM gates, attention mechanism, transformers.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Implement simple CNN in PyTorch: conv layer + ReLU + max pool + FC.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>Use nn.Conv2d, nn.ReLU, nn.MaxPool2d.</details>

# %% [markdown]
# **Q67-Q100.** Continue with CNNs on CIFAR-10, LSTMs, transformers, transfer learning.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
