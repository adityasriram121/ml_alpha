# %% [markdown]
# # Concept 10: Unsupervised Learning (Crash Course Notes)
#
# Finding patterns in unlabeled data.
#
# ## 📖 Readings Reference
# * **ISLP**: Chapter 12 (Clustering).
# * **HOML3**: Chapter 9 (Unsupervised Learning).
#
# ## 📐 Mathematical Foundations
# 1. **K-Means Centroid Update**:
#    $$\mu_k = \frac{1}{|S_k|} \sum_{x_i \in S_k} x_i$$
# 2. **K-Means Inertia (Within-Cluster Sum of Squares)**:
#    $$\text{Inertia} = \sum_{i=1}^m \|x_i - \mu_{c^{(i)}}\|^2$$
#
# ---
#
# ## 💻 Coding Tasks (Your Turn)

# %%
from sklearn.cluster import KMeans

# Task 1: K-Means Clustering
# Instantiate and fit a KMeans model with 3 clusters on data X.
X = np.random.randn(100, 2)
### YOUR CODE HERE
kmeans = None
### END CODE

# %% [markdown]
# ## ❓ Socratic Checkpoints
# 1. Why is K-Means sensitive to the initialization of centroids, and how does K-Means++ solve this?
# 2. Explain the difference between K-Means and DBSCAN regarding shape assumptions.
# 3. How does Hierarchical Clustering build a dendrogram? What are the linkage options (single, complete, average)?
