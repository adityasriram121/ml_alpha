# %% [markdown]
# # 🏋️ Practice Problems: 10_UNSUPERVISED_LEARNING
# ## Clustering & Unsupervised Learning
#
# **Topics**: k-means, hierarchical clustering, DBSCAN, silhouette score
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What is clustering? What's the difference from classification?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Unsupervised: no labels. Find structure in data.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain k-means algorithm step by step.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Initialize, assign to nearest center, update centers, repeat.</details>

# %% [markdown]
# **Q3-Q35.** Continue with more conceptual problems on k-means, hierarchical clustering, DBSCAN, silhouette.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Derive k-means objective: minimize Σ_i Σ_{x in C_i} ||x - μ_i||^2.

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Within-cluster sum of squares.</details>

# %% [markdown]
# **Q37-Q65.** Continue with theoretical problems on silhouette score, hierarchical clustering, DBSCAN.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Apply k-means to Iris with k=3. Visualize clusters. Compare to true labels.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>Use KMeans(n_clusters=3).</details>

# %% [markdown]
# **Q67-Q100.** Continue with silhouette scores, hierarchical clustering, DBSCAN, k selection.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
