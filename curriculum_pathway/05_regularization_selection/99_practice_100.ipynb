# %% [markdown]
# # 🏋️ Practice Problems: 05_REGULARIZATION_SELECTION
# ## Regularization & Model Selection
#
# **Topics**: ridge regression, lasso, elastic net, model comparison, AIC/BIC
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What is regularization? Why does it help prevent overfitting?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Adds penalty on weight magnitude.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain L1 vs L2 regularization. Which does feature selection?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>L1 (lasso) shrinks some coefficients to exactly 0.</details>

# %% [markdown]
# **Q3.** [⭐] What is elastic net? Why combine L1 and L2?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Gets best of both: sparsity (L1) + stability (L2).</details>

# %% [markdown]
# **Q4-Q35.** Continue with more conceptual problems on regularization, model selection, AIC, BIC.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Derive the closed-form solution for ridge regression: w = (X^T X + λI)^{-1} X^T y.

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Minimize MSE + λ||w||^2.</details>

# %% [markdown]
# **Q37-Q65.** Continue with more theoretical problems on ridge, lasso, AIC, degrees of freedom.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Fit ridge regression to Auto data. Try lambda in [0.001, 0.01, 0.1, 1, 10, 100]. Plot train/test MSE vs lambda.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>Use cross_val_score().</details>

# %% [markdown]
# **Q67-Q100.** Continue with lasso, elastic net, AIC/BIC, coefficient paths.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
