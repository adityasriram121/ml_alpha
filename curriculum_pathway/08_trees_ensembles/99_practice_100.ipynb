# %% [markdown]
# # 🏋️ Practice Problems: 08_TREES_ENSEMBLES
# ## Decision Trees & Ensemble Methods
#
# **Topics**: tree splits, gini/entropy, bagging, random forests, boosting
#
# **100 problems**: 35 conceptual + 30 theoretical + 35 practical
# **Difficulty**: ⭐ (easy), ⭐⭐ (medium), ⭐⭐⭐ (hard)

# %% [markdown]
# ## 🧠 Conceptual (Q1-Q35)

# %% [markdown]
# **Q1.** [⭐] What is a decision tree? How does it make predictions?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Recursive splits on features, leaf = predicted class/value.</details>

# %% [markdown]
# **Q2.** [⭐⭐] Explain Gini impurity and entropy. Which is faster to compute?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Gini: 1 - Σp_i^2. Entropy: -Σp_i*log(p_i). Gini is faster.</details>

# %% [markdown]
# **Q3-Q35.** Continue with more conceptual problems on trees, bagging, random forests, boosting.

# %% [markdown]
# ## 📐 Theoretical (Q36-Q65)

# %% [markdown]
# **Q36.** [⭐] Derive Gini impurity: G = 1 - Σp_i^2.

# %% [markdown]
# *Your derivation:*

# %% [markdown]
# <details><summary>💡 Hint</summary>Probability of misclassifying random sample.</details>

# %% [markdown]
# **Q37-Q65.** Continue with theoretical problems on information gain, bagging, boosting convergence.

# %% [markdown]
# ## 💻 Practical (Q66-Q100)

# %% [markdown]
# **Q66.** [⭐] Fit decision tree to Iris. Try max_depth from 1 to 10. Plot train/test accuracy.

# %%
# YOUR CODE HERE

# %% [markdown]
# <details><summary>💡 Hint</summary>Use DecisionTreeClassifier().</details>

# %% [markdown]
# **Q67-Q100.** Continue with random forests, AdaBoost, feature importances, OOB error.

# %% [markdown]
# ---
# ## 🎯 Tips for Success
# 1. Work through problems sequentially
# 2. Use hints generously
# 3. Compare with solutions (when available)
# 4. Revisit harder problems regularly
#
# Good luck! 🚀
